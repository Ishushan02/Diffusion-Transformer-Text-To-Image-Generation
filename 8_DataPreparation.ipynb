# %%
import pandas as pd
import os
import json
import csv
from collections import defaultdict

# %%
capVal2017Path = "dataset/annotations/captions_val2017.json"
with open(capVal2017Path, 'r') as file:
    data = json.load(file)

data.keys()
data['images'][0], data['annotations'][0]
# Out:
# ({'license': 4,
#   'file_name': '000000397133.jpg',
#   'coco_url': 'http://images.cocodataset.org/val2017/000000397133.jpg',
#   'height': 427,
#   'width': 640,
#   'date_captured': '2013-11-14 17:02:52',
#   'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg',
#   'id': 397133},
#  {'image_id': 179765,
#   'id': 38,
#   'caption': 'A black Honda motorcycle parked in front of a garage.'})

# %%
rootDir = 'dataset'
trainCaptions = os.path.join(rootDir, 'annotations', 'captions_train2017.json')
trainImages = os.path.join(rootDir, 'train2017')

valCaptions = os.path.join(rootDir, 'annotations', 'captions_val2017.json')
valImages = os.path.join(rootDir, 'val2017')

# %%
with open(trainCaptions, 'r') as f:
    trainCaption = json.load(f)

with open(valCaptions, 'r') as f:
    valCaption = json.load(f)

# %%
trainCaption['images'], valCaption['images']
# Out:
# ([{'license': 3,
#    'file_name': '000000391895.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000391895.jpg',
#    'height': 360,
#    'width': 640,
#    'date_captured': '2013-11-14 11:18:45',
#    'flickr_url': 'http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg',
#    'id': 391895},
#   {'license': 4,
#    'file_name': '000000522418.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000522418.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-14 11:38:44',
#    'flickr_url': 'http://farm1.staticflickr.com/1/127244861_ab0c0381e7_z.jpg',
#    'id': 522418},
#   {'license': 3,
#    'file_name': '000000184613.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000184613.jpg',
#    'height': 336,
#    'width': 500,
#    'date_captured': '2013-11-14 12:36:29',
#    'flickr_url': 'http://farm3.staticflickr.com/2169/2118578392_1193aa04a0_z.jpg',
#    'id': 184613},
#   {'license': 3,
#    'file_name': '000000318219.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000318219.jpg',
#    'height': 640,
#    'width': 556,
#    'date_captured': '2013-11-14 13:02:53',
#    'flickr_url': 'http://farm5.staticflickr.com/4125/5094763076_813ea2751b_z.jpg',
#    'id': 318219},
#   {'license': 3,
#    'file_name': '000000554625.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000554625.jpg',
#    'height': 640,
#    'width': 426,
#    'date_captured': '2013-11-14 16:03:19',
#    'flickr_url': 'http://farm5.staticflickr.com/4086/5094162993_8f59d8a473_z.jpg',
#    'id': 554625},
#   {'license': 3,
#    'file_name': '000000574769.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000574769.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-14 17:07:59',
#    'flickr_url': 'http://farm8.staticflickr.com/7010/6728227647_3d5a0d55ee_z.jpg',
#    'id': 574769},
#   {'license': 4,
#    'file_name': '000000060623.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000060623.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-14 17:24:15',
#    'flickr_url': 'http://farm7.staticflickr.com/6080/6113512699_37b4c98473_z.jpg',
#    'id': 60623},
#   {'license': 2,
#    'file_name': '000000309022.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000309022.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-14 17:28:23',
#    'flickr_url': 'http://farm4.staticflickr.com/3790/10167396295_e63f2856d0_z.jpg',
#    'id': 309022},
#   {'license': 2,
#    'file_name': '000000005802.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000005802.jpg',
#    'height': 479,
#    'width': 640,
#    'date_captured': '2013-11-14 17:28:25',
#    'flickr_url': 'http://farm4.staticflickr.com/3810/9614287841_1b724dbbc5_z.jpg',
#    'id': 5802},
#   {'license': 2,
#    'file_name': '000000222564.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000222564.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-14 17:30:34',
#    'flickr_url': 'http://farm8.staticflickr.com/7390/10166966765_c96225b556_z.jpg',
#    'id': 222564},
#   {'license': 1,
#    'file_name': '000000118113.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000118113.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-14 17:44:50',
#    'flickr_url': 'http://farm8.staticflickr.com/7030/6555665525_b242809dc2_z.jpg',
#    'id': 118113},
#   {'license': 1,
#    'file_name': '000000193271.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000193271.jpg',
#    'height': 320,
#    'width': 480,
#    'date_captured': '2013-11-14 17:55:04',
#    'flickr_url': 'http://farm4.staticflickr.com/3772/9523928163_3814f02ec5_z.jpg',
#    'id': 193271},
#   {'license': 3,
#    'file_name': '000000224736.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000224736.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-14 18:20:45',
#    'flickr_url': 'http://farm3.staticflickr.com/2727/4397992076_8288fa5165_z.jpg',
#    'id': 224736},
#   {'license': 3,
#    'file_name': '000000483108.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000483108.jpg',
#    'height': 640,
#    'width': 428,
#    'date_captured': '2013-11-14 18:27:53',
#    'flickr_url': 'http://farm3.staticflickr.com/2012/2087034507_2277d9fa27_z.jpg',
#    'id': 483108},
#   {'license': 2,
#    'file_name': '000000403013.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000403013.jpg',
#    'height': 450,
#    'width': 301,
#    'date_captured': '2013-11-14 18:37:28',
#    'flickr_url': 'http://farm8.staticflickr.com/7369/8717355931_ebe09c411b_z.jpg',
#    'id': 403013},
#   {'license': 2,
#    'file_name': '000000374628.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000374628.jpg',
#    'height': 326,
#    'width': 640,
#    'date_captured': '2013-11-14 19:18:11',
#    'flickr_url': 'http://farm5.staticflickr.com/4070/4444442937_5aba7a1c31_z.jpg',
#    'id': 374628},
#   {'license': 3,
#    'file_name': '000000328757.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000328757.jpg',
#    'height': 332,
#    'width': 500,
#    'date_captured': '2013-11-14 19:34:34',
#    'flickr_url': 'http://farm4.staticflickr.com/3079/2532983426_373865b789_z.jpg',
#    'id': 328757},
#   {'license': 3,
#    'file_name': '000000384213.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000384213.jpg',
#    'height': 500,
#    'width': 375,
#    'date_captured': '2013-11-14 19:38:10',
#    'flickr_url': 'http://farm3.staticflickr.com/2184/2139760734_89b784d4d3_z.jpg',
#    'id': 384213},
#   {'license': 3,
#    'file_name': '000000293802.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000293802.jpg',
#    'height': 640,
#    'width': 425,
#    'date_captured': '2013-11-14 20:28:50',
#    'flickr_url': 'http://farm4.staticflickr.com/3017/2502287818_41e4b0c4fb_z.jpg',
#    'id': 293802},
#   {'license': 1,
#    'file_name': '000000086408.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000086408.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-14 20:29:23',
#    'flickr_url': 'http://farm4.staticflickr.com/3668/9463610705_130c967a7b_z.jpg',
#    'id': 86408},
#   {'license': 3,
#    'file_name': '000000372938.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000372938.jpg',
#    'height': 424,
#    'width': 640,
#    'date_captured': '2013-11-14 20:57:14',
#    'flickr_url': 'http://farm4.staticflickr.com/3282/2628517227_1937cc8be0_z.jpg',
#    'id': 372938},
#   {'license': 3,
#    'file_name': '000000386164.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000386164.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-14 21:06:13',
#    'flickr_url': 'http://farm6.staticflickr.com/5216/5384496530_f0aa6628a2_z.jpg',
#    'id': 386164},
#   {'license': 3,
#    'file_name': '000000223648.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000223648.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-14 21:06:15',
#    'flickr_url': 'http://farm6.staticflickr.com/5219/5383892439_6ef5ba6f23_z.jpg',
#    'id': 223648},
#   {'license': 7,
#    'file_name': '000000204805.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000204805.jpg',
#    'height': 346,
#    'width': 500,
#    'date_captured': '2013-11-14 21:33:07',
#    'flickr_url': 'http://farm4.staticflickr.com/3251/2843692498_cb1559002c_z.jpg',
#    'id': 204805},
#   {'license': 3,
#    'file_name': '000000113588.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000113588.jpg',
#    'height': 640,
#    'width': 425,
#    'date_captured': '2013-11-14 21:36:59',
#    'flickr_url': 'http://farm5.staticflickr.com/4103/5094762826_3799070b3d_z.jpg',
#    'id': 113588},
#   {'license': 3,
#    'file_name': '000000384553.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000384553.jpg',
#    'height': 425,
#    'width': 640,
#    'date_captured': '2013-11-14 21:45:37',
#    'flickr_url': 'http://farm5.staticflickr.com/4006/4581234593_5802cfe86f_z.jpg',
#    'id': 384553},
#   {'license': 2,
#    'file_name': '000000337264.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000337264.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-14 21:54:11',
#    'flickr_url': 'http://farm9.staticflickr.com/8005/7284225450_c38ee955ff_z.jpg',
#    'id': 337264},
#   {'license': 2,
#    'file_name': '000000368402.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000368402.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-14 22:22:42',
#    'flickr_url': 'http://farm8.staticflickr.com/7234/6912194164_60704b897c_z.jpg',
#    'id': 368402},
#   {'license': 2,
#    'file_name': '000000012448.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000012448.jpg',
#    'height': 640,
#    'width': 427,
#    'date_captured': '2013-11-14 22:29:22',
#    'flickr_url': 'http://farm4.staticflickr.com/3298/3342841641_a5d277ef9b_z.jpg',
#    'id': 12448},
#   {'license': 3,
#    'file_name': '000000079841.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000079841.jpg',
#    'height': 213,
#    'width': 640,
#    'date_captured': '2013-11-14 22:51:13',
#    'flickr_url': 'http://farm3.staticflickr.com/2862/8776368733_77162fb532_z.jpg',
#    'id': 79841},
#   {'license': 3,
#    'file_name': '000000515289.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000515289.jpg',
#    'height': 640,
#    'width': 639,
#    'date_captured': '2013-11-14 23:37:04',
#    'flickr_url': 'http://farm4.staticflickr.com/3458/3397096735_67bf0c7882_z.jpg',
#    'id': 515289},
#   {'license': 3,
#    'file_name': '000000562150.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000562150.jpg',
#    'height': 516,
#    'width': 640,
#    'date_captured': '2013-11-14 23:45:06',
#    'flickr_url': 'http://farm8.staticflickr.com/7002/6836351539_d19296470f_z.jpg',
#    'id': 562150},
#   {'license': 4,
#    'file_name': '000000542145.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000542145.jpg',
#    'height': 500,
#    'width': 375,
#    'date_captured': '2013-11-14 23:55:14',
#    'flickr_url': 'http://farm4.staticflickr.com/3549/3450899546_cd58d2f025_z.jpg',
#    'id': 542145},
#   {'license': 4,
#    'file_name': '000000412151.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000412151.jpg',
#    'height': 334,
#    'width': 500,
#    'date_captured': '2013-11-15 00:04:33',
#    'flickr_url': 'http://farm4.staticflickr.com/3079/3125146921_d0550129e2_z.jpg',
#    'id': 412151},
#   {'license': 4,
#    'file_name': '000000579003.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000579003.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 00:33:52',
#    'flickr_url': 'http://farm4.staticflickr.com/3344/3579591078_077ce9bc80_z.jpg',
#    'id': 579003},
#   {'license': 4,
#    'file_name': '000000540186.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000540186.jpg',
#    'height': 640,
#    'width': 621,
#    'date_captured': '2013-11-15 00:36:10',
#    'flickr_url': 'http://farm4.staticflickr.com/3560/3680488485_8dea85c816_z.jpg',
#    'id': 540186},
#   {'license': 4,
#    'file_name': '000000242611.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000242611.jpg',
#    'height': 364,
#    'width': 640,
#    'date_captured': '2013-11-15 00:36:13',
#    'flickr_url': 'http://farm3.staticflickr.com/2526/3715306985_0219baa375_z.jpg',
#    'id': 242611},
#   {'license': 4,
#    'file_name': '000000051191.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000051191.jpg',
#    'height': 640,
#    'width': 628,
#    'date_captured': '2013-11-15 00:36:16',
#    'flickr_url': 'http://farm3.staticflickr.com/2545/3715302411_1172efcb7a_z.jpg',
#    'id': 51191},
#   {'license': 3,
#    'file_name': '000000269105.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000269105.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 00:49:55',
#    'flickr_url': 'http://farm6.staticflickr.com/5019/5475842031_265f533bb8_z.jpg',
#    'id': 269105},
#   {'license': 4,
#    'file_name': '000000294832.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000294832.jpg',
#    'height': 429,
#    'width': 640,
#    'date_captured': '2013-11-15 01:02:49',
#    'flickr_url': 'http://farm4.staticflickr.com/3577/3513897232_88bf76fd27_z.jpg',
#    'id': 294832},
#   {'license': 6,
#    'file_name': '000000462565.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000462565.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 01:05:40',
#    'flickr_url': 'http://farm8.staticflickr.com/7396/9146492562_1344ccec28_z.jpg',
#    'id': 462565},
#   {'license': 4,
#    'file_name': '000000144941.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000144941.jpg',
#    'height': 334,
#    'width': 500,
#    'date_captured': '2013-11-15 01:05:44',
#    'flickr_url': 'http://farm4.staticflickr.com/3317/3340149864_434669932a_z.jpg',
#    'id': 144941},
#   {'license': 5,
#    'file_name': '000000173350.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000173350.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 01:18:05',
#    'flickr_url': 'http://farm1.staticflickr.com/120/313090696_ea522e2894_z.jpg',
#    'id': 173350},
#   {'license': 1,
#    'file_name': '000000060760.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000060760.jpg',
#    'height': 500,
#    'width': 375,
#    'date_captured': '2013-11-15 01:24:17',
#    'flickr_url': 'http://farm2.staticflickr.com/1175/1340119212_e1aa46da60_z.jpg',
#    'id': 60760},
#   {'license': 6,
#    'file_name': '000000324266.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000324266.jpg',
#    'height': 425,
#    'width': 640,
#    'date_captured': '2013-11-15 01:28:33',
#    'flickr_url': 'http://farm8.staticflickr.com/7333/10045949924_865301c2bb_z.jpg',
#    'id': 324266},
#   {'license': 3,
#    'file_name': '000000166532.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000166532.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 01:39:00',
#    'flickr_url': 'http://farm8.staticflickr.com/7318/9630780362_d830cfd4dd_z.jpg',
#    'id': 166532},
#   {'license': 3,
#    'file_name': '000000262284.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000262284.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 01:45:50',
#    'flickr_url': 'http://farm8.staticflickr.com/7396/9627540643_b3ec7096c8_z.jpg',
#    'id': 262284},
#   {'license': 1,
#    'file_name': '000000360772.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000360772.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 01:52:38',
#    'flickr_url': 'http://farm1.staticflickr.com/73/198405531_52eac37362_z.jpg',
#    'id': 360772},
#   {'license': 1,
#    'file_name': '000000191381.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000191381.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 01:53:07',
#    'flickr_url': 'http://farm1.staticflickr.com/83/215509478_9f1fb45443_z.jpg',
#    'id': 191381},
#   {'license': 4,
#    'file_name': '000000111076.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000111076.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 02:01:31',
#    'flickr_url': 'http://farm9.staticflickr.com/8513/8582707945_0e85b7e6aa_z.jpg',
#    'id': 111076},
#   {'license': 5,
#    'file_name': '000000340559.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000340559.jpg',
#    'height': 640,
#    'width': 428,
#    'date_captured': '2013-11-15 02:06:07',
#    'flickr_url': 'http://farm9.staticflickr.com/8382/8555424519_937047609c_z.jpg',
#    'id': 340559},
#   {'license': 1,
#    'file_name': '000000258985.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000258985.jpg',
#    'height': 603,
#    'width': 640,
#    'date_captured': '2013-11-15 02:07:38',
#    'flickr_url': 'http://farm5.staticflickr.com/4140/4892317339_fca342106f_z.jpg',
#    'id': 258985},
#   {'license': 1,
#    'file_name': '000000509822.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000509822.jpg',
#    'height': 425,
#    'width': 640,
#    'date_captured': '2013-11-15 02:53:28',
#    'flickr_url': 'http://farm7.staticflickr.com/6095/6220574839_af6b6146b8_z.jpg',
#    'id': 509822},
#   {'license': 6,
#    'file_name': '000000321107.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000321107.jpg',
#    'height': 480,
#    'width': 269,
#    'date_captured': '2013-11-15 03:14:32',
#    'flickr_url': 'http://farm4.staticflickr.com/3038/4555159978_d98b05d459_z.jpg',
#    'id': 321107},
#   {'license': 4,
#    'file_name': '000000229643.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000229643.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 03:16:39',
#    'flickr_url': 'http://farm8.staticflickr.com/7022/6800059483_4064f390e9_z.jpg',
#    'id': 229643},
#   {'license': 6,
#    'file_name': '000000125059.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000125059.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 03:48:13',
#    'flickr_url': 'http://farm8.staticflickr.com/7154/6554273181_9d9c440500_z.jpg',
#    'id': 125059},
#   {'license': 3,
#    'file_name': '000000455483.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000455483.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 04:13:16',
#    'flickr_url': 'http://farm8.staticflickr.com/7388/9630769502_93bdddfa1d_z.jpg',
#    'id': 455483},
#   {'license': 1,
#    'file_name': '000000436141.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000436141.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 04:26:05',
#    'flickr_url': 'http://farm6.staticflickr.com/5270/5870372133_30851db382_z.jpg',
#    'id': 436141},
#   {'license': 6,
#    'file_name': '000000129001.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000129001.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 05:12:40',
#    'flickr_url': 'http://farm6.staticflickr.com/5010/5287787850_a15b664348_z.jpg',
#    'id': 129001},
#   {'license': 5,
#    'file_name': '000000232262.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000232262.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 05:23:22',
#    'flickr_url': 'http://farm9.staticflickr.com/8048/8089005305_a6b2feda80_z.jpg',
#    'id': 232262},
#   {'license': 3,
#    'file_name': '000000061181.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000061181.jpg',
#    'height': 321,
#    'width': 500,
#    'date_captured': '2013-11-15 05:26:41',
#    'flickr_url': 'http://farm4.staticflickr.com/3085/2658286283_8f4cc104c3_z.jpg',
#    'id': 61181},
#   {'license': 1,
#    'file_name': '000000166323.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000166323.jpg',
#    'height': 640,
#    'width': 425,
#    'date_captured': '2013-11-15 05:28:03',
#    'flickr_url': 'http://farm5.staticflickr.com/4082/4811768449_09db6ce99e_z.jpg',
#    'id': 166323},
#   {'license': 2,
#    'file_name': '000000580041.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000580041.jpg',
#    'height': 500,
#    'width': 375,
#    'date_captured': '2013-11-15 05:28:40',
#    'flickr_url': 'http://farm1.staticflickr.com/166/420938681_399d97222a_z.jpg',
#    'id': 580041},
#   {'license': 5,
#    'file_name': '000000326781.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000326781.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 05:49:18',
#    'flickr_url': 'http://farm5.staticflickr.com/4059/4696486422_2da44b4925_z.jpg',
#    'id': 326781},
#   {'license': 3,
#    'file_name': '000000387362.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000387362.jpg',
#    'height': 640,
#    'width': 428,
#    'date_captured': '2013-11-15 06:14:12',
#    'flickr_url': 'http://farm3.staticflickr.com/2798/4429905226_356d73afae_z.jpg',
#    'id': 387362},
#   {'license': 1,
#    'file_name': '000000138079.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000138079.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 06:15:34',
#    'flickr_url': 'http://farm3.staticflickr.com/2493/4508204444_f52fa188e0_z.jpg',
#    'id': 138079},
#   {'license': 4,
#    'file_name': '000000556616.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000556616.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 06:17:51',
#    'flickr_url': 'http://farm3.staticflickr.com/2596/3758496795_c4dc34afb0_z.jpg',
#    'id': 556616},
#   {'license': 4,
#    'file_name': '000000472621.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000472621.jpg',
#    'height': 298,
#    'width': 640,
#    'date_captured': '2013-11-15 06:19:20',
#    'flickr_url': 'http://farm5.staticflickr.com/4064/4456103357_7d98582e82_z.jpg',
#    'id': 472621},
#   {'license': 4,
#    'file_name': '000000192440.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000192440.jpg',
#    'height': 426,
#    'width': 640,
#    'date_captured': '2013-11-15 06:24:48',
#    'flickr_url': 'http://farm5.staticflickr.com/4059/4338841142_0363f7aab4_z.jpg',
#    'id': 192440},
#   {'license': 4,
#    'file_name': '000000086320.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000086320.jpg',
#    'height': 336,
#    'width': 500,
#    'date_captured': '2013-11-15 06:37:06',
#    'flickr_url': 'http://farm5.staticflickr.com/4056/4276257397_9e73708d45_z.jpg',
#    'id': 86320},
#   {'license': 4,
#    'file_name': '000000256668.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000256668.jpg',
#    'height': 500,
#    'width': 375,
#    'date_captured': '2013-11-15 06:42:44',
#    'flickr_url': 'http://farm3.staticflickr.com/2672/4161298186_6974321aaf_z.jpg',
#    'id': 256668},
#   {'license': 1,
#    'file_name': '000000383445.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000383445.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 06:58:19',
#    'flickr_url': 'http://farm4.staticflickr.com/3175/3044562512_d798c9484b_z.jpg',
#    'id': 383445},
#   {'license': 6,
#    'file_name': '000000565797.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000565797.jpg',
#    'height': 454,
#    'width': 640,
#    'date_captured': '2013-11-15 07:16:08',
#    'flickr_url': 'http://farm7.staticflickr.com/6175/6194686185_723b21149c_z.jpg',
#    'id': 565797},
#   {'license': 2,
#    'file_name': '000000081922.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000081922.jpg',
#    'height': 426,
#    'width': 640,
#    'date_captured': '2013-11-15 10:13:11',
#    'flickr_url': 'http://farm7.staticflickr.com/6205/6138566813_307440bd53_z.jpg',
#    'id': 81922},
#   {'license': 6,
#    'file_name': '000000050125.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000050125.jpg',
#    'height': 413,
#    'width': 640,
#    'date_captured': '2013-11-15 10:46:53',
#    'flickr_url': 'http://farm3.staticflickr.com/2100/1544852657_ffccbbc3d1_z.jpg',
#    'id': 50125},
#   {'license': 4,
#    'file_name': '000000364521.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000364521.jpg',
#    'height': 426,
#    'width': 640,
#    'date_captured': '2013-11-15 11:45:21',
#    'flickr_url': 'http://farm9.staticflickr.com/8005/7579122494_4a3d393783_z.jpg',
#    'id': 364521},
#   {'license': 3,
#    'file_name': '000000394892.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000394892.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 11:54:07',
#    'flickr_url': 'http://farm8.staticflickr.com/7261/7562949882_01918407aa_z.jpg',
#    'id': 394892},
#   {'license': 3,
#    'file_name': '000000001146.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000001146.jpg',
#    'height': 640,
#    'width': 427,
#    'date_captured': '2013-11-15 11:55:43',
#    'flickr_url': 'http://farm3.staticflickr.com/2145/1861401504_e46f53623a_z.jpg',
#    'id': 1146},
#   {'license': 3,
#    'file_name': '000000310391.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000310391.jpg',
#    'height': 360,
#    'width': 640,
#    'date_captured': '2013-11-15 12:07:31',
#    'flickr_url': 'http://farm9.staticflickr.com/8014/7689410230_e64b99e184_z.jpg',
#    'id': 310391},
#   {'license': 4,
#    'file_name': '000000097434.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000097434.jpg',
#    'height': 266,
#    'width': 640,
#    'date_captured': '2013-11-15 12:18:56',
#    'flickr_url': 'http://farm8.staticflickr.com/7122/7856942124_de238af8cb_z.jpg',
#    'id': 97434},
#   {'license': 1,
#    'file_name': '000000463836.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000463836.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 12:18:57',
#    'flickr_url': 'http://farm4.staticflickr.com/3292/2733229050_f8c798b46d_z.jpg',
#    'id': 463836},
#   {'license': 1,
#    'file_name': '000000241876.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000241876.jpg',
#    'height': 375,
#    'width': 500,
#    'date_captured': '2013-11-15 12:50:05',
#    'flickr_url': 'http://farm3.staticflickr.com/2269/2097484971_522f958fc7_z.jpg',
#    'id': 241876},
#   {'license': 4,
#    'file_name': '000000156832.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000156832.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 12:57:27',
#    'flickr_url': 'http://farm4.staticflickr.com/3268/2442836764_ccf9703f1c_z.jpg',
#    'id': 156832},
#   {'license': 6,
#    'file_name': '000000270721.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000270721.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 13:30:24',
#    'flickr_url': 'http://farm3.staticflickr.com/2031/1832502548_563a970191_z.jpg',
#    'id': 270721},
#   {'license': 4,
#    'file_name': '000000462341.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000462341.jpg',
#    'height': 640,
#    'width': 427,
#    'date_captured': '2013-11-15 13:31:08',
#    'flickr_url': 'http://farm3.staticflickr.com/2696/4472391245_b1bb40bfe1_z.jpg',
#    'id': 462341},
#   {'license': 1,
#    'file_name': '000000310103.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000310103.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 13:38:21',
#    'flickr_url': 'http://farm5.staticflickr.com/4011/4655232440_382e0f36e6_z.jpg',
#    'id': 310103},
#   {'license': 4,
#    'file_name': '000000032992.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000032992.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 13:40:43',
#    'flickr_url': 'http://farm5.staticflickr.com/4131/4947024342_d1a15857cd_z.jpg',
#    'id': 32992},
#   {'license': 3,
#    'file_name': '000000122851.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000122851.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 13:50:42',
#    'flickr_url': 'http://farm7.staticflickr.com/6105/6358592127_5b47f1c54f_z.jpg',
#    'id': 122851},
#   {'license': 1,
#    'file_name': '000000540763.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000540763.jpg',
#    'height': 640,
#    'width': 425,
#    'date_captured': '2013-11-15 13:55:16',
#    'flickr_url': 'http://farm7.staticflickr.com/6092/6237466550_cd054b3dff_z.jpg',
#    'id': 540763},
#   {'license': 2,
#    'file_name': '000000138246.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000138246.jpg',
#    'height': 424,
#    'width': 640,
#    'date_captured': '2013-11-15 14:02:56',
#    'flickr_url': 'http://farm2.staticflickr.com/1432/5133505754_90b663bf4f_z.jpg',
#    'id': 138246},
#   {'license': 3,
#    'file_name': '000000197254.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000197254.jpg',
#    'height': 640,
#    'width': 428,
#    'date_captured': '2013-11-15 14:06:58',
#    'flickr_url': 'http://farm4.staticflickr.com/3556/3452031005_d6cc337946_z.jpg',
#    'id': 197254},
#   {'license': 1,
#    'file_name': '000000032907.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000032907.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 14:08:35',
#    'flickr_url': 'http://farm4.staticflickr.com/3608/3499798248_1381426e82_z.jpg',
#    'id': 32907},
#   {'license': 6,
#    'file_name': '000000251252.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000251252.jpg',
#    'height': 500,
#    'width': 375,
#    'date_captured': '2013-11-15 14:12:33',
#    'flickr_url': 'http://farm3.staticflickr.com/2151/2274335153_e574622321_z.jpg',
#    'id': 251252},
#   {'license': 1,
#    'file_name': '000000037675.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000037675.jpg',
#    'height': 415,
#    'width': 640,
#    'date_captured': '2013-11-15 14:13:03',
#    'flickr_url': 'http://farm4.staticflickr.com/3330/3412312325_4a735ae4a8_z.jpg',
#    'id': 37675},
#   {'license': 1,
#    'file_name': '000000159537.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000159537.jpg',
#    'height': 640,
#    'width': 425,
#    'date_captured': '2013-11-15 14:20:08',
#    'flickr_url': 'http://farm5.staticflickr.com/4083/5047823673_1bebe388e7_z.jpg',
#    'id': 159537},
#   {'license': 3,
#    'file_name': '000000268556.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000268556.jpg',
#    'height': 640,
#    'width': 640,
#    'date_captured': '2013-11-15 14:29:00',
#    'flickr_url': 'http://farm3.staticflickr.com/2876/9620553260_a812cd5ca1_z.jpg',
#    'id': 268556},
#   {'license': 6,
#    'file_name': '000000271177.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000271177.jpg',
#    'height': 500,
#    'width': 375,
#    'date_captured': '2013-11-15 14:35:03',
#    'flickr_url': 'http://farm2.staticflickr.com/1337/1360004143_fcf8aaad45_z.jpg',
#    'id': 271177},
#   {'license': 3,
#    'file_name': '000000075051.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000075051.jpg',
#    'height': 375,
#    'width': 500,
#    'date_captured': '2013-11-15 14:58:13',
#    'flickr_url': 'http://farm4.staticflickr.com/3071/3024475423_cb79891b71_z.jpg',
#    'id': 75051},
#   {'license': 3,
#    'file_name': '000000549399.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000549399.jpg',
#    'height': 424,
#    'width': 640,
#    'date_captured': '2013-11-15 15:02:10',
#    'flickr_url': 'http://farm9.staticflickr.com/8424/7491622748_da89dbcf72_z.jpg',
#    'id': 549399},
#   {'license': 3,
#    'file_name': '000000085160.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000085160.jpg',
#    'height': 425,
#    'width': 640,
#    'date_captured': '2013-11-15 15:14:52',
#    'flickr_url': 'http://farm6.staticflickr.com/5246/5321173112_675e10fb7f_z.jpg',
#    'id': 85160},
#   {'license': 3,
#    'file_name': '000000559665.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000559665.jpg',
#    'height': 397,
#    'width': 640,
#    'date_captured': '2013-11-15 15:25:41',
#    'flickr_url': 'http://farm8.staticflickr.com/7322/9296558150_0fe28321a1_z.jpg',
#    'id': 559665},
#   {'license': 4,
#    'file_name': '000000019358.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000019358.jpg',
#    'height': 426,
#    'width': 640,
#    'date_captured': '2013-11-15 15:40:32',
#    'flickr_url': 'http://farm4.staticflickr.com/3441/3991098638_b029e135a2_z.jpg',
#    'id': 19358},
#   {'license': 4,
#    'file_name': '000000459912.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000459912.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 15:42:29',
#    'flickr_url': 'http://farm8.staticflickr.com/7391/9081512157_75d5cef187_z.jpg',
#    'id': 459912},
#   {'license': 4,
#    'file_name': '000000015827.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000015827.jpg',
#    'height': 640,
#    'width': 427,
#    'date_captured': '2013-11-15 15:42:35',
#    'flickr_url': 'http://farm6.staticflickr.com/5330/9081531225_47044e007e_z.jpg',
#    'id': 15827},
#   {'license': 4,
#    'file_name': '000000394240.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000394240.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 15:42:40',
#    'flickr_url': 'http://farm6.staticflickr.com/5497/9083616900_0930242ca6_z.jpg',
#    'id': 394240},
#   {'license': 6,
#    'file_name': '000000510755.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000510755.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 16:28:39',
#    'flickr_url': 'http://farm6.staticflickr.com/5070/5680563777_16bd981fa7_z.jpg',
#    'id': 510755},
#   {'license': 4,
#    'file_name': '000000175831.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000175831.jpg',
#    'height': 640,
#    'width': 508,
#    'date_captured': '2013-11-15 16:29:37',
#    'flickr_url': 'http://farm8.staticflickr.com/7244/7351203646_b97040e8c0_z.jpg',
#    'id': 175831},
#   {'license': 1,
#    'file_name': '000000079472.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000079472.jpg',
#    'height': 481,
#    'width': 640,
#    'date_captured': '2013-11-15 16:49:13',
#    'flickr_url': 'http://farm1.staticflickr.com/54/125746482_f5a296e693_z.jpg',
#    'id': 79472},
#   {'license': 1,
#    'file_name': '000000250108.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000250108.jpg',
#    'height': 481,
#    'width': 640,
#    'date_captured': '2013-11-15 17:13:57',
#    'flickr_url': 'http://farm1.staticflickr.com/18/92714041_ea63d5d400_z.jpg',
#    'id': 250108},
#   {'license': 3,
#    'file_name': '000000315601.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000315601.jpg',
#    'height': 424,
#    'width': 640,
#    'date_captured': '2013-11-15 17:35:04',
#    'flickr_url': 'http://farm9.staticflickr.com/8092/8393450656_d03daf4b03_z.jpg',
#    'id': 315601},
#   {'license': 1,
#    'file_name': '000000437218.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000437218.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 17:37:36',
#    'flickr_url': 'http://farm2.staticflickr.com/1329/1017578715_853fd4bdab_z.jpg',
#    'id': 437218},
#   {'license': 2,
#    'file_name': '000000503707.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000503707.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 17:55:21',
#    'flickr_url': 'http://farm9.staticflickr.com/8340/8239634401_6079e1b043_z.jpg',
#    'id': 503707},
#   {'license': 4,
#    'file_name': '000000074331.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000074331.jpg',
#    'height': 640,
#    'width': 427,
#    'date_captured': '2013-11-15 18:38:36',
#    'flickr_url': 'http://farm6.staticflickr.com/5287/5351312216_04d4d6dcae_z.jpg',
#    'id': 74331},
#   {'license': 1,
#    'file_name': '000000579664.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000579664.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 18:47:08',
#    'flickr_url': 'http://farm5.staticflickr.com/4122/4920334778_2050b51c82_z.jpg',
#    'id': 579664},
#   {'license': 4,
#    'file_name': '000000369763.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000369763.jpg',
#    'height': 289,
#    'width': 640,
#    'date_captured': '2013-11-15 19:16:52',
#    'flickr_url': 'http://farm9.staticflickr.com/8177/7897919854_d1dbf69832_z.jpg',
#    'id': 369763},
#   {'license': 6,
#    'file_name': '000000199951.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000199951.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 19:22:12',
#    'flickr_url': 'http://farm4.staticflickr.com/3709/9547207842_24eab0e3b2_z.jpg',
#    'id': 199951},
#   {'license': 4,
#    'file_name': '000000452684.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000452684.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-15 19:34:46',
#    'flickr_url': 'http://farm6.staticflickr.com/5292/5548702761_16c868feb0_z.jpg',
#    'id': 452684},
#   {'license': 4,
#    'file_name': '000000213687.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000213687.jpg',
#    'height': 479,
#    'width': 640,
#    'date_captured': '2013-11-15 20:04:12',
#    'flickr_url': 'http://farm8.staticflickr.com/7100/7168869419_2b523a5033_z.jpg',
#    'id': 213687},
#   {'license': 4,
#    'file_name': '000000108094.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000108094.jpg',
#    'height': 640,
#    'width': 471,
#    'date_captured': '2013-11-15 20:04:17',
#    'flickr_url': 'http://farm9.staticflickr.com/8006/7360945292_a9df5a0ee4_z.jpg',
#    'id': 108094},
#   {'license': 2,
#    'file_name': '000000527040.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000527040.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 20:19:37',
#    'flickr_url': 'http://farm2.staticflickr.com/1283/946074610_d181fc83e2_z.jpg',
#    'id': 527040},
#   {'license': 2,
#    'file_name': '000000350341.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000350341.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 20:19:42',
#    'flickr_url': 'http://farm2.staticflickr.com/1049/945242827_b8fda3e2d5_z.jpg',
#    'id': 350341},
#   {'license': 2,
#    'file_name': '000000550529.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000550529.jpg',
#    'height': 612,
#    'width': 612,
#    'date_captured': '2013-11-15 21:14:19',
#    'flickr_url': 'http://farm8.staticflickr.com/7069/6927091799_8e37b8e2ac_z.jpg',
#    'id': 550529},
#   {'license': 1,
#    'file_name': '000000432176.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000432176.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 21:53:38',
#    'flickr_url': 'http://farm3.staticflickr.com/2476/3793737301_e0c3ce2f15_z.jpg',
#    'id': 432176},
#   {'license': 6,
#    'file_name': '000000281533.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000281533.jpg',
#    'height': 434,
#    'width': 640,
#    'date_captured': '2013-11-15 22:51:40',
#    'flickr_url': 'http://farm4.staticflickr.com/3525/3233723212_8a19b94fb0_z.jpg',
#    'id': 281533},
#   {'license': 2,
#    'file_name': '000000369826.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000369826.jpg',
#    'height': 478,
#    'width': 640,
#    'date_captured': '2013-11-15 23:01:04',
#    'flickr_url': 'http://farm3.staticflickr.com/2859/8929261675_36617ededf_z.jpg',
#    'id': 369826},
#   {'license': 1,
#    'file_name': '000000551334.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000551334.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 23:51:36',
#    'flickr_url': 'http://farm1.staticflickr.com/34/121381826_36fc92c7f7_z.jpg',
#    'id': 551334},
#   {'license': 1,
#    'file_name': '000000291380.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000291380.jpg',
#    'height': 375,
#    'width': 500,
#    'date_captured': '2013-11-16 00:11:22',
#    'flickr_url': 'http://farm4.staticflickr.com/3120/2760079876_57900b7517_z.jpg',
#    'id': 291380},
#   {'license': 1,
#    'file_name': '000000368978.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000368978.jpg',
#    'height': 486,
#    'width': 640,
#    'date_captured': '2013-11-16 01:58:10',
#    'flickr_url': 'http://farm8.staticflickr.com/7117/6929206214_f2386ac59e_z.jpg',
#    'id': 368978},
#   {'license': 1,
#    'file_name': '000000077123.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000077123.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-16 02:46:39',
#    'flickr_url': 'http://farm7.staticflickr.com/6205/6084630545_fbeeab0d08_z.jpg',
#    'id': 77123},
#   {'license': 4,
#    'file_name': '000000513681.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000513681.jpg',
#    'height': 469,
#    'width': 640,
#    'date_captured': '2013-11-16 03:41:34',
#    'flickr_url': 'http://farm6.staticflickr.com/5024/5743986251_a3d5ed53b0_z.jpg',
#    'id': 513681},
#   {'license': 1,
#    'file_name': '000000437370.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000437370.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-16 05:12:56',
#    'flickr_url': 'http://farm3.staticflickr.com/2805/9829358484_8538ab0d2b_z.jpg',
#    'id': 437370},
#   {'license': 1,
#    'file_name': '000000078371.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000078371.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-16 05:13:01',
#    'flickr_url': 'http://farm8.staticflickr.com/7433/9829402976_fbb8b10588_z.jpg',
#    'id': 78371},
#   {'license': 6,
#    'file_name': '000000560623.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000560623.jpg',
#    'height': 360,
#    'width': 640,
#    'date_captured': '2013-11-16 05:55:47',
#    'flickr_url': 'http://farm8.staticflickr.com/7401/9213783677_99cb7b4272_z.jpg',
#    'id': 560623},
#   {'license': 6,
#    'file_name': '000000289173.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000289173.jpg',
#    'height': 360,
#    'width': 640,
#    'date_captured': '2013-11-16 05:58:47',
#    'flickr_url': 'http://farm4.staticflickr.com/3802/9216684964_52c0be9049_z.jpg',
#    'id': 289173},
#   {'license': 6,
#    'file_name': '000000052759.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000052759.jpg',
#    'height': 360,
#    'width': 640,
#    'date_captured': '2013-11-16 05:58:52',
#    'flickr_url': 'http://farm6.staticflickr.com/5540/9216686042_36c6cbc6ec_z.jpg',
#    'id': 52759},
#   {'license': 6,
#    'file_name': '000000568623.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000568623.jpg',
#    'height': 416,
#    'width': 640,
#    'date_captured': '2013-11-16 12:13:26',
#    'flickr_url': 'http://farm9.staticflickr.com/8012/6997162288_60bb1fecb2_z.jpg',
#    'id': 568623},
#   {'license': 1,
#    'file_name': '000000128939.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000128939.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-16 12:16:29',
#    'flickr_url': 'http://farm9.staticflickr.com/8150/7479996486_318bc18967_z.jpg',
#    'id': 128939},
#   {'license': 6,
#    'file_name': '000000339974.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000339974.jpg',
#    'height': 640,
#    'width': 427,
#    'date_captured': '2013-11-16 12:27:22',
#    'flickr_url': 'http://farm8.staticflickr.com/7157/6649936035_d8e6e0d825_z.jpg',
#    'id': 339974},
#   {'license': 3,
#    'file_name': '000000561100.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000561100.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-16 12:29:19',
#    'flickr_url': 'http://farm2.staticflickr.com/1257/1394269810_525e77f6c9_z.jpg',
#    'id': 561100},
#   {'license': 3,
#    'file_name': '000000150410.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000150410.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-16 12:29:28',
#    'flickr_url': 'http://farm2.staticflickr.com/1022/1393383885_9b71eef41b_z.jpg',
#    'id': 150410},
#   {'license': 3,
#    'file_name': '000000009426.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000009426.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-16 12:29:39',
#    'flickr_url': 'http://farm2.staticflickr.com/1349/1393395723_787bef7a5b_z.jpg',
#    'id': 9426},
#   {'license': 5,
#    'file_name': '000000014869.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000014869.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-16 12:39:28',
#    'flickr_url': 'http://farm2.staticflickr.com/1422/1300647503_fd599eb7a9_z.jpg',
#    'id': 14869},
#   {'license': 5,
#    'file_name': '000000281221.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000281221.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-16 13:27:23',
#    'flickr_url': 'http://farm8.staticflickr.com/7259/7468511358_56aaa9f099_z.jpg',
#    'id': 281221},
#   {'license': 1,
#    'file_name': '000000108169.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000108169.jpg',
#    'height': 375,
#    'width': 500,
#    'date_captured': '2013-11-16 13:49:29',
#    'flickr_url': 'http://farm1.staticflickr.com/53/151999573_c95d4f676b_z.jpg',
#    'id': 108169},
#   {'license': 3,
#    'file_name': '000000440575.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000440575.jpg',
#    'height': 412,
#    'width': 640,
#    'date_captured': '2013-11-16 13:52:21',
#    'flickr_url': 'http://farm8.staticflickr.com/7023/6833888065_dec5b637e8_z.jpg',
#    'id': 440575},
#   {'license': 3,
#    'file_name': '000000354533.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000354533.jpg',
#    'height': 310,
#    'width': 640,
#    'date_captured': '2013-11-16 13:58:27',
#    'flickr_url': 'http://farm3.staticflickr.com/2519/4126738647_cc436c111b_z.jpg',
#    'id': 354533},
#   {'license': 3,
#    'file_name': '000000545959.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000545959.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-16 14:06:08',
#    'flickr_url': 'http://farm7.staticflickr.com/6051/6364564991_5c2c02fafa_z.jpg',
#    'id': 545959},
#   {'license': 1,
#    'file_name': '000000511058.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000511058.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-16 14:09:13',
#    'flickr_url': 'http://farm5.staticflickr.com/4065/4717007124_924927b0f0_z.jpg',
#    'id': 511058},
#   {'license': 6,
#    'file_name': '000000091227.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000091227.jpg',
#    'height': 428,
#    'width': 640,
#    'date_captured': '2013-11-16 15:02:38',
#    'flickr_url': 'http://farm3.staticflickr.com/2798/4471185641_dfedf9fbff_z.jpg',
#    'id': 91227},
#   {'license': 2,
#    'file_name': '000000242139.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000242139.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-16 15:05:16',
#    'flickr_url': 'http://farm4.staticflickr.com/3078/2700607772_6417078a61_z.jpg',
#    'id': 242139},
#   {'license': 2,
#    'file_name': '000000334321.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000334321.jpg',
#    'height': 360,
#    'width': 640,
#    'date_captured': '2013-11-16 15:15:19',
#    'flickr_url': 'http://farm4.staticflickr.com/3198/2816571233_7c043af98c_z.jpg',
#    'id': 334321},
#   {'license': 6,
#    'file_name': '000000381021.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000381021.jpg',
#    'height': 640,
#    'width': 476,
#    'date_captured': '2013-11-16 15:24:30',
#    'flickr_url': 'http://farm8.staticflickr.com/7345/8723678741_053d6bf106_z.jpg',
#    'id': 381021},
#   {'license': 3,
#    'file_name': '000000170629.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000170629.jpg',
#    'height': 431,
#    'width': 640,
#    'date_captured': '2013-11-16 15:37:23',
#    'flickr_url': 'http://farm3.staticflickr.com/2793/4249154362_efb640bf8c_z.jpg',
#    'id': 170629},
#   {'license': 1,
#    'file_name': '000000207797.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000207797.jpg',
#    'height': 466,
#    'width': 640,
#    'date_captured': '2013-11-16 15:58:49',
#    'flickr_url': 'http://farm8.staticflickr.com/7416/9936976455_478de1d6b4_z.jpg',
#    'id': 207797},
#   {'license': 3,
#    'file_name': '000000179558.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000179558.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-16 16:05:40',
#    'flickr_url': 'http://farm8.staticflickr.com/7416/10257914944_d2ef25995d_z.jpg',
#    'id': 179558},
#   {'license': 4,
#    'file_name': '000000368117.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000368117.jpg',
#    'height': 425,
#    'width': 640,
#    'date_captured': '2013-11-16 16:09:53',
#    'flickr_url': 'http://farm5.staticflickr.com/4143/4747872021_cd8c1ee91b_z.jpg',
#    'id': 368117},
#   {'license': 1,
#    'file_name': '000000015085.jpg',
#    'coco_url': 'http://images.cocodataset.org/train2017/000000015085.jpg',
#    'height': 426,
#    'width': 640,
# ...
#    'date_captured': '2013-11-20 18:27:55',
#    'flickr_url': 'http://farm3.staticflickr.com/2773/4104976058_0762616336_z.jpg',
#    'id': 184384},
#   {'license': 1,
#    'file_name': '000000426329.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000426329.jpg',
#    'height': 428,
#    'width': 640,
#    'date_captured': '2013-11-20 18:45:22',
#    'flickr_url': 'http://farm3.staticflickr.com/2857/9116789659_8992c5f2b7_z.jpg',
#    'id': 426329},
#   {'license': 1,
#    'file_name': '000000128476.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000128476.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-20 19:13:02',
#    'flickr_url': 'http://farm3.staticflickr.com/2200/2280574742_54e5538d3f_z.jpg',
#    'id': 128476},
#   {'license': 3,
#    'file_name': '000000414034.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000414034.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-20 20:53:55',
#    'flickr_url': 'http://farm4.staticflickr.com/3200/2879305925_82a9a40dd8_z.jpg',
#    'id': 414034},
#   {'license': 3,
#    'file_name': '000000450488.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000450488.jpg',
#    'height': 500,
#    'width': 334,
#    'date_captured': '2013-11-20 21:49:32',
#    'flickr_url': 'http://farm3.staticflickr.com/2291/1804855461_498b813a38_z.jpg',
#    'id': 450488},
#   {'license': 1,
#    'file_name': '000000099182.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000099182.jpg',
#    'height': 334,
#    'width': 500,
#    'date_captured': '2013-11-20 22:16:22',
#    'flickr_url': 'http://farm4.staticflickr.com/3420/3268858658_c84b892026_z.jpg',
#    'id': 99182},
#   {'license': 2,
#    'file_name': '000000051738.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000051738.jpg',
#    'height': 375,
#    'width': 500,
#    'date_captured': '2013-11-20 23:25:11',
#    'flickr_url': 'http://farm2.staticflickr.com/1439/684337390_1d37ec3d36_z.jpg',
#    'id': 51738},
#   {'license': 1,
#    'file_name': '000000099039.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000099039.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-20 23:59:40',
#    'flickr_url': 'http://farm3.staticflickr.com/2535/5843392082_e63b00a5c0_z.jpg',
#    'id': 99039},
#   {'license': 1,
#    'file_name': '000000075456.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000075456.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-21 00:14:41',
#    'flickr_url': 'http://farm3.staticflickr.com/2552/3999892430_303c36cf4b_z.jpg',
#    'id': 75456},
#   {'license': 4,
#    'file_name': '000000134882.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000134882.jpg',
#    'height': 639,
#    'width': 640,
#    'date_captured': '2013-11-21 00:31:52',
#    'flickr_url': 'http://farm9.staticflickr.com/8249/8643440732_42cbe68c0f_z.jpg',
#    'id': 134882},
#   {'license': 3,
#    'file_name': '000000442323.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000442323.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-21 01:49:16',
#    'flickr_url': 'http://farm4.staticflickr.com/3249/2848744285_b65d8df0c4_z.jpg',
#    'id': 442323},
#   {'license': 4,
#    'file_name': '000000232489.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000232489.jpg',
#    'height': 640,
#    'width': 640,
#    'date_captured': '2013-11-21 02:31:32',
#    'flickr_url': 'http://farm8.staticflickr.com/7239/7163918053_22e5ab1e70_z.jpg',
#    'id': 232489},
#   {'license': 3,
#    'file_name': '000000351823.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000351823.jpg',
#    'height': 640,
#    'width': 508,
#    'date_captured': '2013-11-21 02:37:02',
#    'flickr_url': 'http://farm9.staticflickr.com/8255/8631855203_4905df9470_z.jpg',
#    'id': 351823},
#   {'license': 3,
#    'file_name': '000000065736.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000065736.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-21 02:41:42',
#    'flickr_url': 'http://farm9.staticflickr.com/8221/8445094517_4923151564_z.jpg',
#    'id': 65736},
#   {'license': 4,
#    'file_name': '000000001000.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000001000.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-21 05:13:59',
#    'flickr_url': 'http://farm5.staticflickr.com/4115/4906536419_6113bd7de4_z.jpg',
#    'id': 1000},
#   {'license': 1,
#    'file_name': '000000379842.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000379842.jpg',
#    'height': 360,
#    'width': 640,
#    'date_captured': '2013-11-21 20:36:56',
#    'flickr_url': 'http://farm5.staticflickr.com/4009/4646199083_5fee687df6_z.jpg',
#    'id': 379842},
#   {'license': 3,
#    'file_name': '000000013923.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000013923.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-21 21:17:47',
#    'flickr_url': 'http://farm9.staticflickr.com/8550/8973469217_ddac383dc5_z.jpg',
#    'id': 13923},
#   {'license': 3,
#    'file_name': '000000559543.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000559543.jpg',
#    'height': 333,
#    'width': 500,
#    'date_captured': '2013-11-21 21:31:03',
#    'flickr_url': 'http://farm4.staticflickr.com/3084/3167056823_4b3292345b_z.jpg',
#    'id': 559543},
#   {'license': 3,
#    'file_name': '000000185890.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000185890.jpg',
#    'height': 640,
#    'width': 509,
#    'date_captured': '2013-11-21 21:39:32',
#    'flickr_url': 'http://farm4.staticflickr.com/3090/2704593814_037ac1aab8_z.jpg',
#    'id': 185890},
#   {'license': 6,
#    'file_name': '000000357978.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000357978.jpg',
#    'height': 375,
#    'width': 500,
#    'date_captured': '2013-11-21 22:06:25',
#    'flickr_url': 'http://farm3.staticflickr.com/2215/2466709397_a2c68700cf_z.jpg',
#    'id': 357978},
#   {'license': 3,
#    'file_name': '000000129492.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000129492.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-21 23:54:00',
#    'flickr_url': 'http://farm1.staticflickr.com/186/436805170_a6de951acb_z.jpg',
#    'id': 129492},
#   {'license': 3,
#    'file_name': '000000261097.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000261097.jpg',
#    'height': 500,
#    'width': 333,
#    'date_captured': '2013-11-22 02:36:20',
#    'flickr_url': 'http://farm3.staticflickr.com/2543/4112985756_309d6e3aa1_z.jpg',
#    'id': 261097},
#   {'license': 3,
#    'file_name': '000000410510.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000410510.jpg',
#    'height': 445,
#    'width': 640,
#    'date_captured': '2013-11-22 02:39:55',
#    'flickr_url': 'http://farm3.staticflickr.com/2527/3995461066_7ec7526016_z.jpg',
#    'id': 410510},
#   {'license': 3,
#    'file_name': '000000039951.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000039951.jpg',
#    'height': 445,
#    'width': 640,
#    'date_captured': '2013-11-23 02:49:46',
#    'flickr_url': 'http://farm4.staticflickr.com/3469/3970726342_e4330fd0fa_z.jpg',
#    'id': 39951},
#   {'license': 2,
#    'file_name': '000000306700.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000306700.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-23 03:33:51',
#    'flickr_url': 'http://farm5.staticflickr.com/4048/4195119942_cfce5d2086_z.jpg',
#    'id': 306700},
#   {'license': 3,
#    'file_name': '000000146457.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000146457.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-23 05:06:20',
#    'flickr_url': 'http://farm4.staticflickr.com/3563/3378875139_c2c7f131d2_z.jpg',
#    'id': 146457},
#   {'license': 3,
#    'file_name': '000000214224.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000214224.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-24 00:15:12',
#    'flickr_url': 'http://farm1.staticflickr.com/61/207838237_b05794eacf_z.jpg',
#    'id': 214224},
#   {'license': 1,
#    'file_name': '000000332845.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000332845.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-24 02:22:14',
#    'flickr_url': 'http://farm6.staticflickr.com/5070/5687759830_5eb0305fa2_z.jpg',
#    'id': 332845},
#   {'license': 2,
#    'file_name': '000000255483.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000255483.jpg',
#    'height': 500,
#    'width': 452,
#    'date_captured': '2013-11-24 04:47:06',
#    'flickr_url': 'http://farm2.staticflickr.com/1083/526468485_6035b5409e_z.jpg',
#    'id': 255483},
#   {'license': 1,
#    'file_name': '000000222455.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000222455.jpg',
#    'height': 612,
#    'width': 612,
#    'date_captured': '2013-11-24 05:05:36',
#    'flickr_url': 'http://farm9.staticflickr.com/8534/8641398667_448ac286f1_z.jpg',
#    'id': 222455},
#   {'license': 1,
#    'file_name': '000000187271.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000187271.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-24 10:58:38',
#    'flickr_url': 'http://farm5.staticflickr.com/4039/4636910713_133158a6d5_z.jpg',
#    'id': 187271},
#   {'license': 2,
#    'file_name': '000000462629.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000462629.jpg',
#    'height': 426,
#    'width': 640,
#    'date_captured': '2013-11-24 11:49:35',
#    'flickr_url': 'http://farm3.staticflickr.com/2025/2492052980_3670e0f17a_z.jpg',
#    'id': 462629},
#   {'license': 4,
#    'file_name': '000000544565.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000544565.jpg',
#    'height': 640,
#    'width': 640,
#    'date_captured': '2013-11-24 14:11:39',
#    'flickr_url': 'http://farm9.staticflickr.com/8385/8637201534_da86391cc8_z.jpg',
#    'id': 544565},
#   {'license': 4,
#    'file_name': '000000369771.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000369771.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-24 14:32:03',
#    'flickr_url': 'http://farm8.staticflickr.com/7238/7250057624_e38c0d9517_z.jpg',
#    'id': 369771},
#   {'license': 1,
#    'file_name': '000000035963.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000035963.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-24 14:54:39',
#    'flickr_url': 'http://farm9.staticflickr.com/8468/8362875916_3622526977_z.jpg',
#    'id': 35963},
#   {'license': 1,
#    'file_name': '000000289516.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000289516.jpg',
#    'height': 640,
#    'width': 304,
#    'date_captured': '2013-11-24 15:49:35',
#    'flickr_url': 'http://farm8.staticflickr.com/7229/7181685405_4f9b4272ac_z.jpg',
#    'id': 289516},
#   {'license': 1,
#    'file_name': '000000334309.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000334309.jpg',
#    'height': 427,
#    'width': 640,
#    'date_captured': '2013-11-24 22:13:59',
#    'flickr_url': 'http://farm9.staticflickr.com/8451/8030935807_ac38a77d75_z.jpg',
#    'id': 334309},
#   {'license': 4,
#    'file_name': '000000452084.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000452084.jpg',
#    'height': 639,
#    'width': 640,
#    'date_captured': '2013-11-24 22:21:06',
#    'flickr_url': 'http://farm4.staticflickr.com/3702/10209222973_bda6223a9f_z.jpg',
#    'id': 452084},
#   {'license': 4,
#    'file_name': '000000301718.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000301718.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-25 15:02:06',
#    'flickr_url': 'http://farm4.staticflickr.com/3763/9132300748_f22266f91b_z.jpg',
#    'id': 301718},
#   {'license': 4,
#    'file_name': '000000429598.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000429598.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-14 16:19:13',
#    'flickr_url': 'http://farm8.staticflickr.com/7162/6617685485_877d5cee57_z.jpg',
#    'id': 429598},
#   {'license': 1,
#    'file_name': '000000165257.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000165257.jpg',
#    'height': 359,
#    'width': 640,
#    'date_captured': '2013-11-14 17:00:49',
#    'flickr_url': 'http://farm7.staticflickr.com/6161/6148741765_ca0a35b3a0_z.jpg',
#    'id': 165257},
#   {'license': 1,
#    'file_name': '000000093437.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000093437.jpg',
#    'height': 361,
#    'width': 640,
#    'date_captured': '2013-11-14 20:33:42',
#    'flickr_url': 'http://farm4.staticflickr.com/3284/3087312929_11b2a967e0_z.jpg',
#    'id': 93437},
#   {'license': 4,
#    'file_name': '000000413552.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000413552.jpg',
#    'height': 640,
#    'width': 426,
#    'date_captured': '2013-11-14 20:56:28',
#    'flickr_url': 'http://farm4.staticflickr.com/3339/3672181666_cfe25af65d_z.jpg',
#    'id': 413552},
#   {'license': 6,
#    'file_name': '000000062025.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000062025.jpg',
#    'height': 640,
#    'width': 480,
#    'date_captured': '2013-11-15 00:35:03',
#    'flickr_url': 'http://farm4.staticflickr.com/3599/3631609738_18ee406290_z.jpg',
#    'id': 62025},
#   {'license': 1,
#    'file_name': '000000017379.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000017379.jpg',
#    'height': 640,
#    'width': 478,
#    'date_captured': '2013-11-15 01:16:56',
#    'flickr_url': 'http://farm6.staticflickr.com/5123/5316824279_9f0a0584c7_z.jpg',
#    'id': 17379},
#   {'license': 1,
#    'file_name': '000000176778.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000176778.jpg',
#    'height': 640,
#    'width': 427,
#    'date_captured': '2013-11-15 01:49:27',
#    'flickr_url': 'http://farm9.staticflickr.com/8525/8546503892_17447f6b25_z.jpg',
#    'id': 176778},
#   {'license': 3,
#    'file_name': '000000104572.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000104572.jpg',
#    'height': 419,
#    'width': 640,
#    'date_captured': '2013-11-15 02:19:16',
#    'flickr_url': 'http://farm9.staticflickr.com/8224/8315344109_22818bbfbe_z.jpg',
#    'id': 104572},
#   {'license': 4,
#    'file_name': '000000090108.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000090108.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 02:24:34',
#    'flickr_url': 'http://farm4.staticflickr.com/3511/5818186852_061520ff7a_z.jpg',
#    'id': 90108},
#   {'license': 2,
#    'file_name': '000000157124.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000157124.jpg',
#    'height': 424,
#    'width': 640,
#    'date_captured': '2013-11-15 03:22:32',
#    'flickr_url': 'http://farm8.staticflickr.com/7277/6881159188_cedb19b9b0_z.jpg',
#    'id': 157124},
#   {'license': 4,
#    'file_name': '000000089556.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000089556.jpg',
#    'height': 480,
#    'width': 640,
#    'date_captured': '2013-11-15 05:44:24',
#    'flickr_url': 'http://farm7.staticflickr.com/6093/6210323230_57fab50c4b_z.jpg',
#    'id': 89556},
#   {'license': 1,
#    'file_name': '000000266206.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000266206.jpg',
#    'height': 640,
#    'width': 427,
#    'date_captured': '2013-11-15 05:53:15',
#    'flickr_url': 'http://farm3.staticflickr.com/2856/9211916412_42e79d869e_z.jpg',
#    'id': 266206},
#   {'license': 6,
#    'file_name': '000000086220.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000086220.jpg',
#    'height': 428,
#    'width': 640,
#    'date_captured': '2013-11-15 05:56:59',
#    'flickr_url': 'http://farm9.staticflickr.com/8374/8438120381_b8b40a66b2_z.jpg',
#    'id': 86220},
#   {'license': 3,
#    'file_name': '000000508602.jpg',
#    'coco_url': 'http://images.cocodataset.org/val2017/000000508602.jpg',
#    'height': 429,
#    'width': 500,
#    'date_captured': '2013-11-15 06:51:06',
#    'flickr_url': 'http://farm1.staticflickr.com/31/89958837_3946184e5f_z.jpg',
#    'id': 508602},
#   ...])

# %%
len(trainCaption['images']), len(valCaption['images'])
# Out:
# (118287, 5000)

# %%
image_id_to_filename = {img['id']: img['file_name'] for img in data['images']}

# %%
trainCaption['annotations']
# Out:
# [{'image_id': 203564,
#   'id': 37,
#   'caption': 'A bicycle replica with a clock as the front wheel.'},
#  {'image_id': 322141,
#   'id': 49,
#   'caption': 'A room with blue walls and a white sink and door.'},
#  {'image_id': 16977,
#   'id': 89,
#   'caption': 'A car that seems to be parked illegally behind a legally parked car'},
#  {'image_id': 106140,
#   'id': 98,
#   'caption': 'A large passenger airplane flying through the air.'},
#  {'image_id': 106140,
#   'id': 101,
#   'caption': 'There is a GOL plane taking off in a partly cloudy sky.'},
#  {'image_id': 322141,
#   'id': 109,
#   'caption': 'Blue and white color scheme in a small bathroom.'},
#  {'image_id': 322141,
#   'id': 121,
#   'caption': 'This is a blue and white bathroom with a wall sink and a lifesaver on the wall.'},
#  {'image_id': 322141,
#   'id': 163,
#   'caption': 'A blue boat themed bathroom with a life preserver on the wall'},
#  {'image_id': 203564, 'id': 181, 'caption': 'The bike has a clock as a tire.'},
#  {'image_id': 16977,
#   'id': 185,
#   'caption': 'two cars parked on the sidewalk on the street'},
#  {'image_id': 106140,
#   'id': 221,
#   'caption': 'An airplane that is, either, landing or just taking off.'},
#  {'image_id': 322141,
#   'id': 250,
#   'caption': 'A bathroom with walls that are painted baby blue.'},
#  {'image_id': 571635,
#   'id': 342,
#   'caption': 'A bathroom with a toilet, sink, and shower.'},
#  {'image_id': 301837,
#   'id': 391,
#   'caption': 'A long empty, minimal modern skylit home kitchen.'},
#  {'image_id': 315702,
#   'id': 437,
#   'caption': 'A bathroom sink with toiletries on the counter.'},
#  {'image_id': 315702,
#   'id': 452,
#   'caption': 'A bathroom sink and various personal hygiene items.'},
#  {'image_id': 189634,
#   'id': 455,
#   'caption': 'This is an open box containing four cucumbers.'},
#  {'image_id': 472598,
#   'id': 456,
#   'caption': 'An old-fashioned green station wagon is parked on a shady driveway.'},
#  {'image_id': 162113,
#   'id': 464,
#   'caption': 'A gas stove next to a stainless steel kitchen sink and countertop.'},
#  {'image_id': 203564,
#   'id': 478,
#   'caption': 'A black metal bicycle with a clock inside the front wheel.'},
#  {'image_id': 126657,
#   'id': 565,
#   'caption': 'Several motorcycles riding down the road in formation.'},
#  {'image_id': 285421,
#   'id': 589,
#   'caption': 'A black cat is inside a white toilet.'},
#  {'image_id': 16977,
#   'id': 626,
#   'caption': 'City street with parked cars and a bench.'},
#  {'image_id': 71988,
#   'id': 699,
#   'caption': 'A man in a wheelchair and another sitting on a bench that is overlooking the water.'},
#  {'image_id': 193622,
#   'id': 701,
#   'caption': 'A man sits with a traditionally decorated cow'},
#  {'image_id': 459912,
#   'id': 748,
#   'caption': 'Rows of motor bikes and helmets in a city'},
#  {'image_id': 548498,
#   'id': 754,
#   'caption': 'A cute kitten is sitting in a dish on a table.'},
#  {'image_id': 315702,
#   'id': 791,
#   'caption': 'A messy bathroom countertop perched atop black cabinetry.'},
#  {'image_id': 52087,
#   'id': 827,
#   'caption': 'A man getting a drink from a water fountain that is a toilet.'},
#  {'image_id': 189634,
#   'id': 833,
#   'caption': 'An open food container box with four unknown food items.'},
#  {'image_id': 472598,
#   'id': 834,
#   'caption': 'An old teal colored car parked on the street.'},
#  {'image_id': 119964,
#   'id': 891,
#   'caption': 'A person holding a skateboard overlooks a dead field of crops.'},
#  {'image_id': 126657,
#   'id': 931,
#   'caption': 'A group of motorcycle riders driving past buildings.'},
#  {'image_id': 230610,
#   'id': 935,
#   'caption': 'A bathroom with a sink and shower curtain with a map print.'},
#  {'image_id': 226419,
#   'id': 939,
#   'caption': 'A random plane in the sky flying alone'},
#  {'image_id': 226419,
#   'id': 945,
#   'caption': 'An airplane flying high in the blue sky. '},
#  {'image_id': 218026,
#   'id': 961,
#   'caption': 'A brown and black horse in the middle of the city eating grass.'},
#  {'image_id': 352538,
#   'id': 974,
#   'caption': 'A brown purse is sitting on a green bench.'},
#  {'image_id': 202913,
#   'id': 1034,
#   'caption': 'Half of a white cake with coconuts on top.'},
#  {'image_id': 202658,
#   'id': 1037,
#   'caption': 'An old toilet with a hello kitty cover top. '},
#  {'image_id': 79472,
#   'id': 1104,
#   'caption': 'Office space with office equipment on desk top.'},
#  {'image_id': 346071,
#   'id': 1113,
#   'caption': "Two husky's hanging out of the car windows."},
#  {'image_id': 6672,
#   'id': 1132,
#   'caption': 'The back door with a window in the kitchen.'},
#  {'image_id': 419074,
#   'id': 1137,
#   'caption': 'Jet liner flying off into the distance on an overcast day'},
#  {'image_id': 382406,
#   'id': 1221,
#   'caption': 'A woman is walking a dog in the city.'},
#  {'image_id': 16977,
#   'id': 1229,
#   'caption': 'Cars try to maneuver into parking spaces along a densely packed city street. '},
#  {'image_id': 346071,
#   'id': 1248,
#   'caption': 'Dogs stick their heads out of car windows'},
#  {'image_id': 119964,
#   'id': 1302,
#   'caption': 'A person sits on a patch of grass observing the scenery.'},
#  {'image_id': 175948,
#   'id': 1327,
#   'caption': 'A tiny bathroom with only a toilet and a shelf.'},
#  {'image_id': 573223,
#   'id': 1373,
#   'caption': 'A little girl in a public bathroom for kids.'},
#  {'image_id': 52087,
#   'id': 1400,
#   'caption': 'A boy drinking water from a toilet water fountain.'},
#  {'image_id': 402514,
#   'id': 1436,
#   'caption': 'A picture of a man playing a violin in a kitchen.'},
#  {'image_id': 230610,
#   'id': 1484,
#   'caption': 'A small and crowded bathroom with little furnishing '},
#  {'image_id': 407286,
#   'id': 1494,
#   'caption': "A trio of dogs sitting in their owner's lap in a red convertible."},
#  {'image_id': 82673,
#   'id': 1562,
#   'caption': 'A small car is parked in front of a scooter'},
#  {'image_id': 382406,
#   'id': 1620,
#   'caption': 'A woman and her dog walking down a sidewalk next to a fence with some flowers. '},
#  {'image_id': 141172,
#   'id': 1637,
#   'caption': 'A door with a sticker of a cat door on it'},
#  {'image_id': 104326,
#   'id': 1693,
#   'caption': 'A pinewood and green modern themed kitchen area.'},
#  {'image_id': 402514,
#   'id': 1706,
#   'caption': 'A man is playing violin in his kitchen'},
#  {'image_id': 581177,
#   'id': 1766,
#   'caption': 'A kitchen is shown with wooden cabinets and a wooden celling.'},
#  {'image_id': 267802,
#   'id': 1774,
#   'caption': 'A group of people riding mopeds in a busy street. '},
#  {'image_id': 208408,
#   'id': 1828,
#   'caption': 'A person walking in the rain on the sidewalk. '},
#  {'image_id': 581177,
#   'id': 1865,
#   'caption': 'A recently remodeled kitchen with marble and wooden furnishings.'},
#  {'image_id': 560591,
#   'id': 1886,
#   'caption': 'a modern flush toilet in a bathroom with tile. '},
#  {'image_id': 189634,
#   'id': 1907,
#   'caption': 'A small box filled with four green vegetables. '},
#  {'image_id': 472598,
#   'id': 1908,
#   'caption': 'A classic car sitting beside the road with a surfboard on top. '},
#  {'image_id': 507362,
#   'id': 1933,
#   'caption': 'Fog is in the air at an intersection with several traffic lights.'},
#  {'image_id': 407286,
#   'id': 2028,
#   'caption': "Three little dogs looking out a car window while sitting on a woman's lap. "},
#  {'image_id': 52087,
#   'id': 2045,
#   'caption': 'A young man drinking from a water fountain in the shape of a toilet.'},
#  {'image_id': 57429,
#   'id': 2049,
#   'caption': 'An airplane with its landing wheels out landing. '},
#  {'image_id': 153184,
#   'id': 2076,
#   'caption': 'Little birds sitting on the shoulder of a giraffe. '},
#  {'image_id': 382406,
#   'id': 2091,
#   'caption': 'A woman walking her dog on the sidewalk.'},
#  {'image_id': 571970, 'id': 2099, 'caption': 'a man with a bike at a marina'},
#  {'image_id': 153184,
#   'id': 2121,
#   'caption': "The top of a giraffe's head has birds on it."},
#  {'image_id': 57429,
#   'id': 2139,
#   'caption': 'A plane that is taking off at an airport'},
#  {'image_id': 133680,
#   'id': 2152,
#   'caption': 'A man is sitting on a bench next to a bike.'},
#  {'image_id': 139011,
#   'id': 2154,
#   'caption': 'People are waiting for the bus near a bus stop.'},
#  {'image_id': 6672,
#   'id': 2155,
#   'caption': 'The kitchen has a white door with a window.'},
#  {'image_id': 104326,
#   'id': 2167,
#   'caption': 'A kitchen and dining room area with a large window.'},
#  {'image_id': 505386,
#   'id': 2192,
#   'caption': 'four urinals in a public restroom with a window'},
#  {'image_id': 106140,
#   'id': 2219,
#   'caption': 'An red and white airplane is in the cloudy sky.'},
#  {'image_id': 285421,
#   'id': 2242,
#   'caption': 'A black cat drinking water from a toilet'},
#  {'image_id': 581177,
#   'id': 2258,
#   'caption': 'Well kept kitchen with marble counter tops and stainless steel fridge'},
#  {'image_id': 79472,
#   'id': 2376,
#   'caption': 'A hope office setup of computers and printers.'},
#  {'image_id': 208408,
#   'id': 2383,
#   'caption': 'A person walking through the rain with an umbrella.'},
#  {'image_id': 107990,
#   'id': 2405,
#   'caption': 'A small child climbs atop a large motorcycle'},
#  {'image_id': 527510,
#   'id': 2450,
#   'caption': 'A large U.S Air Force plain sits on an asphalt ramp.'},
#  {'image_id': 5247,
#   'id': 2473,
#   'caption': 'A black and white photo of an older man skiing.'},
#  {'image_id': 505386,
#   'id': 2576,
#   'caption': 'A bathroom with four urinals on the wall.'},
#  {'image_id': 301837,
#   'id': 2599,
#   'caption': 'A picture of a modern looking kitchen area\n'},
#  {'image_id': 79472,
#   'id': 2607,
#   'caption': 'a home office with laptop, printer, scanner, and extra monitor'},
#  {'image_id': 5247,
#   'id': 2620,
#   'caption': 'Two people on the snow for cross country skiing.'},
#  {'image_id': 107960,
#   'id': 2655,
#   'caption': 'Riding a motorcycle down a street that has no one else on it.'},
#  {'image_id': 162113,
#   'id': 2666,
#   'caption': 'A kitchen stove, sink, and counter with stuff on it.'},
#  {'image_id': 133680,
#   'id': 2686,
#   'caption': 'A man is sitting on a bench next to a bicycle.'},
#  {'image_id': 139011,
#   'id': 2688,
#   'caption': 'A crowd of people are waiting to get on a red bus.'},
#  {'image_id': 285421,
#   'id': 2761,
#   'caption': 'A cat drinking water from a toilet in a bathroom.'},
#  {'image_id': 507362,
#   'id': 2830,
#   'caption': 'An intersection during a cold and foggy night.'},
#  {'image_id': 208408,
#   'id': 2884,
#   'caption': 'A person walking in the rain while holding an umbrella.'},
#  {'image_id': 407286,
#   'id': 2919,
#   'caption': 'A woman driver has three dogs in the seat with her.'},
#  {'image_id': 57429,
#   'id': 2946,
#   'caption': 'A man takes a picture of an airplane taking off.'},
#  {'image_id': 410627,
#   'id': 2961,
#   'caption': 'The young man is stirring his pot of food with a wooden spoon.'},
#  {'image_id': 232223,
#   'id': 3001,
#   'caption': 'A fighter jet is flying at a fast speed.'},
#  {'image_id': 22793,
#   'id': 3043,
#   'caption': 'A public bathroom with a bunch of urinals.'},
#  {'image_id': 436456,
#   'id': 3106,
#   'caption': 'The airplane is on the runway with two young men standing by.'},
#  {'image_id': 581177,
#   'id': 3125,
#   'caption': 'A beautiful new kitchen with natural wood cabinets.'},
#  {'image_id': 368402,
#   'id': 3192,
#   'caption': 'The woman in the kitchen is holding a huge pan.'},
#  {'image_id': 107990,
#   'id': 3200,
#   'caption': 'A young boy riding a motorcycle next to a silver car.'},
#  {'image_id': 135161,
#   'id': 3205,
#   'caption': 'A toilet sits next to a window and in front of a shower.'},
#  {'image_id': 382406,
#   'id': 3237,
#   'caption': 'A woman walks her dog along a city street.'},
#  {'image_id': 107990,
#   'id': 3302,
#   'caption': 'A little baby is sitting on a huge motorcycle.'},
#  {'image_id': 505386,
#   'id': 3362,
#   'caption': 'An old bathroom with a row of urinals.'},
#  {'image_id': 581177,
#   'id': 3365,
#   'caption': 'A neat, wood filled kitchen is photographed as if for a real estate ad.'},
#  {'image_id': 407286,
#   'id': 3417,
#   'caption': 'A woman and her three dogs in a car.'},
#  {'image_id': 230610,
#   'id': 3446,
#   'caption': 'A small bathroom with a shower curtain with the NYC Subway map on it. '},
#  {'image_id': 230610,
#   'id': 3455,
#   'caption': 'A bathroom with a map as a shower curtain. '},
#  {'image_id': 16977,
#   'id': 3506,
#   'caption': 'A couple of cars parked in a busy street sidewalk.'},
#  {'image_id': 106140,
#   'id': 3560,
#   'caption': 'A passenger plane taking off into the sky. '},
#  {'image_id': 6672,
#   'id': 3577,
#   'caption': 'A kitchen door next to a kitchen sing and counter top.'},
#  {'image_id': 178761,
#   'id': 3586,
#   'caption': 'A dog and a goat with their noses touching at fence.'},
#  {'image_id': 301837,
#   'id': 3694,
#   'caption': 'A narrow kitchen ending with a chrome refrigerator.'},
#  {'image_id': 107990,
#   'id': 3710,
#   'caption': 'A little boy sitting alone on a motorcycle.'},
#  {'image_id': 573223,
#   'id': 3728,
#   'caption': 'A girl standing next to a toilet in a bathroom.'},
#  {'image_id': 491000,
#   'id': 3753,
#   'caption': 'Pedestrians walking down a sidewalk next to a small street.'},
#  {'image_id': 368402,
#   'id': 3759,
#   'caption': 'A chef carrying a large pan inside of a kitchen.'},
#  {'image_id': 419074,
#   'id': 3762,
#   'caption': 'An airplane flying away in a cloudy sky.'},
#  {'image_id': 571635,
#   'id': 3765,
#   'caption': 'A full bathroom with a wicker laundry basket.'},
#  {'image_id': 71988,
#   'id': 3840,
#   'caption': 'Two people sitting on dock looking at the ocean.'},
#  {'image_id': 538092,
#   'id': 3903,
#   'caption': 'A man standing in a kitchen while closing a cupboard door.'},
#  {'image_id': 548498,
#   'id': 4027,
#   'caption': 'A small white cat on a large bowl.'},
#  {'image_id': 267802,
#   'id': 4036,
#   'caption': 'People riding bikes and cars down the street. '},
#  {'image_id': 226419,
#   'id': 4047,
#   'caption': 'A silver color jet flying through the clear sky.'},
#  {'image_id': 505386,
#   'id': 4052,
#   'caption': 'A row of urinals in with an open window above them.'},
#  {'image_id': 202913,
#   'id': 4100,
#   'caption': 'The coconut cake on a red plate is half gone.'},
#  {'image_id': 560591,
#   'id': 4118,
#   'caption': 'A toilet and trashcan in a white bathroom.'},
#  {'image_id': 571970,
#   'id': 4142,
#   'caption': 'A man stands next to his bike at the marina.'},
#  {'image_id': 71988,
#   'id': 4173,
#   'caption': 'Two older people sitting down in front of a beach.'},
#  {'image_id': 571970,
#   'id': 4190,
#   'caption': 'an old man standing next to a bike and a chain fence.'},
#  {'image_id': 230610,
#   'id': 4193,
#   'caption': 'A bathroom with pedestal sink and mirror over it.'},
#  {'image_id': 205577,
#   'id': 4205,
#   'caption': 'A photograph of a kitchen inside a house.'},
#  {'image_id': 508672,
#   'id': 4220,
#   'caption': 'a bike leaning on a metal fence next to some flowing water. '},
#  {'image_id': 52087,
#   'id': 4319,
#   'caption': 'A young person has his face close to the toilet bowl.'},
#  {'image_id': 419074,
#   'id': 4329,
#   'caption': 'A plane that is flying in a clear blue sky.'},
#  {'image_id': 119964,
#   'id': 4347,
#   'caption': 'A person holding a skate board sitting in an empty open field.'},
#  {'image_id': 352538,
#   'id': 4355,
#   'caption': 'a brown purse abandoned on a green bench.'},
#  {'image_id': 507362,
#   'id': 4372,
#   'caption': 'Empty fog covered streets in the night amongst traffic lights.'},
#  {'image_id': 334015,
#   'id': 4386,
#   'caption': 'a small toilet stall with a toilet brush and 3 rolls of toilet paper '},
#  {'image_id': 202913,
#   'id': 4397,
#   'caption': 'A half eaten dessert cake sitting on a cake plate.'},
#  {'image_id': 27842,
#   'id': 4451,
#   'caption': 'A dual sink vanity with mirrors above the sinks.'},
#  {'image_id': 52087,
#   'id': 4571,
#   'caption': 'A man taking a drink from a water fountain.'},
#  {'image_id': 5247,
#   'id': 4594,
#   'caption': 'The old man cross country skis through the forest.'},
#  {'image_id': 527510,
#   'id': 4604,
#   'caption': 'A large propeller airplane sitting on a tarmac.'},
#  {'image_id': 459912,
#   'id': 4633,
#   'caption': 'A lot of motorbikes line up down a busy street.'},
#  {'image_id': 153184,
#   'id': 4653,
#   'caption': 'Three birds sit on the back of a giraffe. '},
#  {'image_id': 358606,
#   'id': 4710,
#   'caption': 'A fireplace with a fire built in it.'},
#  {'image_id': 153184,
#   'id': 4731,
#   'caption': 'A giraffe with 3 birds on his fur.'},
#  {'image_id': 71988,
#   'id': 4740,
#   'caption': 'An old couple at the beach during the day.'},
#  {'image_id': 567730,
#   'id': 4774,
#   'caption': 'The sign of a restaurant in the outside of the store.'},
#  {'image_id': 193622,
#   'id': 4781,
#   'caption': 'A decorative man sits on the ground with a cow.'},
#  {'image_id': 567730,
#   'id': 4840,
#   'caption': 'A sign on a building advertising an Italian restaurant.'},
#  {'image_id': 202658,
#   'id': 4844,
#   'caption': 'A toilet with a Hello Kitty symbol on it.'},
#  {'image_id': 22793,
#   'id': 4852,
#   'caption': 'A picture of a woman hangs on the wall above the urinals.'},
#  {'image_id': 133680,
#   'id': 4855,
#   'caption': 'A man sits on a street bench by a bike. '},
#  {'image_id': 139011,
#   'id': 4857,
#   'caption': 'A crowd of people get ready to board a bus in the city.'},
#  {'image_id': 571970,
#   'id': 4949,
#   'caption': 'A man holding some break standing by a bicycle.'},
#  {'image_id': 175948,
#   'id': 4957,
#   'caption': 'Small bathroom with a toilet and a sink.'},
#  {'image_id': 505386,
#   'id': 4985,
#   'caption': 'A row of urinals stand beneath a open window.'},
#  {'image_id': 560591,
#   'id': 5006,
#   'caption': 'A white toilet sits on a tile floor.'},
#  {'image_id': 61259,
#   'id': 5008,
#   'caption': 'an airport with one plane flying away and the other sitting on the runway'},
#  {'image_id': 554037,
#   'id': 5010,
#   'caption': 'a counter with vegetables, knife and cutting board on it. '},
#  {'image_id': 5394,
#   'id': 5018,
#   'caption': 'A boat that looks like a car moves through the water. '},
#  {'image_id': 5394,
#   'id': 5024,
#   'caption': 'A car modified to drive in the water on a lake.'},
#  {'image_id': 455384,
#   'id': 5173,
#   'caption': 'A delivery truck with an advertisement for Entourage.'},
#  {'image_id': 249352,
#   'id': 5174,
#   'caption': 'A black and white toilet with a plunger.'},
#  {'image_id': 301837,
#   'id': 5209,
#   'caption': 'A narrow kitchen is decorated in shades of white, gray, and black.'},
#  {'image_id': 5247,
#   'id': 5227,
#   'caption': 'A younger man and an older man skiing in the forest.'},
#  {'image_id': 348306,
#   'id': 5283,
#   'caption': 'A bike leaning against a sign in Scotland.'},
#  {'image_id': 348306,
#   'id': 5292,
#   'caption': 'A bike in front of a scenic welcome sign. '},
#  {'image_id': 104326,
#   'id': 5338,
#   'caption': 'A green kitchen with wooden counters and bright lights. '},
#  {'image_id': 162113,
#   'id': 5369,
#   'caption': 'A kitchen with a stove, sink, and drying area. '},
#  {'image_id': 548498,
#   'id': 5377,
#   'caption': 'A small kitten is sitting in a bowl. '},
#  {'image_id': 189634,
#   'id': 5384,
#   'caption': 'An opened box of four chocolate bananas. '},
#  {'image_id': 472598,
#   'id': 5385,
#   'caption': 'An old green car parked on the side of the street.'},
#  {'image_id': 107990,
#   'id': 5387,
#   'caption': 'A toddler sitting on a motorcycle in a parking lot.'},
#  {'image_id': 61259,
#   'id': 5431,
#   'caption': 'jumbo jet sits on the tarmac while another takes off'},
#  {'image_id': 554037,
#   'id': 5433,
#   'caption': 'asparragus, lemons and a bowl of rice on a counter top'},
#  {'image_id': 285421,
#   'id': 5440,
#   'caption': 'A cat puts her head inside of a toilet. '},
#  {'image_id': 455384,
#   'id': 5458,
#   'caption': 'A large van features an ad for a television show.'},
#  {'image_id': 249352,
#   'id': 5459,
#   'caption': 'A toilet has a rug, and a plunger next to it.'},
#  {'image_id': 57429,
#   'id': 5520,
#   'caption': 'A large jet takes off from an airport runway.'},
#  {'image_id': 71988,
#   'id': 5535,
#   'caption': 'A person on a bench, and one on a wheelchair sitting by a seawall looking out toward the ocean'},
#  {'image_id': 475593,
#   'id': 5537,
#   'caption': 'Women father around a desk and machinery in a factory.'},
#  {'image_id': 407286,
#   'id': 5568,
#   'caption': "Three dogs on the lap of a woman in the driver's seat of a convertible."},
#  {'image_id': 107960,
#   'id': 5580,
#   'caption': "The view from a motorcyclist's point of view, looking down a street."},
#  {'image_id': 5394,
#   'id': 5618,
#   'caption': 'A car modified to be a boat on the water.'},
#  {'image_id': 145523,
#   'id': 5653,
#   'caption': 'A few items sit on top of a toilet in a bathroom stall.'},
#  {'image_id': 567730,
#   'id': 5749,
#   'caption': 'A sign for an Italian restaurant hangs outside a building.'},
#  {'image_id': 107960,
#   'id': 5757,
#   'caption': 'A man rides a motorcycle down an empty street next to houses.'},
#  {'image_id': 143370,
#   'id': 5786,
#   'caption': 'A bathroom with a poster of an ugly face above the toilette.'},
#  {'image_id': 27842,
#   'id': 5795,
#   'caption': 'A long marble like bath room vanity with a stool, two sink basins with mirrors and lights over them'},
#  {'image_id': 6672,
#   'id': 5812,
#   'caption': 'A sink next to a large white door '},
#  {'image_id': 279806,
#   'id': 5835,
#   'caption': 'A dirt bike rider doing a stunt jump in the air'},
#  {'image_id': 491000,
#   'id': 5862,
#   'caption': 'People walking on a city street with light traffic.'},
#  {'image_id': 334015,
#   'id': 5871,
#   'caption': 'A clean, European toilet with toilet paper and cleaning brush.'},
#  {'image_id': 135161,
#   'id': 5884,
#   'caption': 'A bathroom with only a toilet and tub with the wall covered in plastic'},
#  {'image_id': 153184,
#   'id': 5922,
#   'caption': 'A flock of birds sits on top of a large giraffe.'},
#  {'image_id': 59171,
#   'id': 5945,
#   'caption': 'A couple of birds fly through a blue cloudy sky.'},
#  {'image_id': 346071,
#   'id': 5958,
#   'caption': 'Two husky dogs ride in a car with their heads hanging out windows.'},
#  {'image_id': 369826,
#   'id': 6018,
#   'caption': 'A picture advertising Arizona tourism in an airport'},
#  {'image_id': 402514,
#   'id': 6023,
#   'caption': 'A man is playing a fiddle in his kitchen.'},
#  {'image_id': 352538,
#   'id': 6032,
#   'caption': "A woman's purse sitting on a park bench."},
#  {'image_id': 178761,
#   'id': 6079,
#   'caption': 'A dog greets a sheep that is in a sheep pen.'},
#  {'image_id': 193622,
#   'id': 6101,
#   'caption': 'A man sits next to his horse in an alley in costume.'},
#  {'image_id': 61259,
#   'id': 6106,
#   'caption': 'A Virgin Australia airline on the tarmac. '},
#  {'image_id': 554037,
#   'id': 6108,
#   'caption': 'The preparation of salmon, asparagus and lemons. '},
#  {'image_id': 126657,
#   'id': 6127,
#   'caption': 'A group of people are riding motorcycles on a road through a town. '},
#  {'image_id': 358606,
#   'id': 6165,
#   'caption': 'A living room containing a modern fireplace and miscellaneous items '},
#  {'image_id': 567730,
#   'id': 6190,
#   'caption': 'Italian Reaffaello restaurant sign at front of building.'},
#  {'image_id': 119964,
#   'id': 6216,
#   'caption': 'A child with a skateboard sitting on the grass and looking at an empty field'},
#  {'image_id': 285421,
#   'id': 6241,
#   'caption': 'A cat is drinking water out of a toilet.'},
#  {'image_id': 560591,
#   'id': 6269,
#   'caption': 'A toilet in a bathroom that is next to a trash can'},
#  {'image_id': 107960,
#   'id': 6282,
#   'caption': 'The view of the street from the perspective of the rider of a motorcycle'},
#  {'image_id': 79472,
#   'id': 6297,
#   'caption': 'The computer desk in the corner is by a window.'},
#  {'image_id': 145523,
#   'id': 6301,
#   'caption': 'A dirty toilet in a small bathroom.with items on top.'},
#  {'image_id': 267802,
#   'id': 6319,
#   'caption': 'Motorists and bicyclists in a busy city square.'},
#  {'image_id': 508672,
#   'id': 6371,
#   'caption': 'A bicycle parked next to a flooded river'},
#  {'image_id': 104326,
#   'id': 6394,
#   'caption': 'A bright room with green walls and cabinets.'},
#  {'image_id': 162113,
#   'id': 6401,
#   'caption': 'This is a kitchen with dishes and a silver sink.'},
#  {'image_id': 410627,
#   'id': 6444,
#   'caption': 'A man enjoys cooking food in a pan'},
#  {'image_id': 175948,
#   'id': 6475,
#   'caption': 'A narrow bathroom has a white door on its side'},
#  {'image_id': 346071,
#   'id': 6501,
#   'caption': 'Two happy dogs have their head out the car window.'},
#  {'image_id': 400552,
#   'id': 6562,
#   'caption': 'A variety of pots are stored in a nook by a fireplace.'},
#  {'image_id': 315702,
#   'id': 6566,
#   'caption': 'A bathroom vanity with cabinets and basin sink and several grooming products scattered across it'},
#  {'image_id': 218026,
#   'id': 6583,
#   'caption': 'Two horses eating grass near a parking lot. '},
#  {'image_id': 348306,
#   'id': 6588,
#   'caption': 'a welcome to Scotland sign with a bicycle leaning on it'},
#  {'image_id': 189634,
#   'id': 6614,
#   'caption': 'An open box contains an unknown, purple object'},
#  {'image_id': 472598,
#   'id': 6615,
#   'caption': 'An antique, turquoise car is parked at the curb'},
#  {'image_id': 203564,
#   'id': 6637,
#   'caption': 'A bicycle figurine in which the front wheel is replaced with a clock\n'},
#  {'image_id': 193622,
#   'id': 6647,
#   'caption': 'Guy and cow are sitting on the floor '},
#  {'image_id': 238836,
#   'id': 6666,
#   'caption': 'A car is stopped at a red light'},
#  {'image_id': 369826,
#   'id': 6672,
#   'caption': 'A television that is sitting next to signs'},
#  {'image_id': 178761,
#   'id': 6676,
#   'caption': 'Two animals get close through a fence. '},
#  {'image_id': 400552,
#   'id': 6700,
#   'caption': 'A room contains baskets and has a fireplace. '},
#  {'image_id': 475593,
#   'id': 6725,
#   'caption': 'A photo set of two women at work'},
#  {'image_id': 264461,
#   'id': 6752,
#   'caption': 'A bathroom with a traditional toilet next to a floor toilet.'},
#  {'image_id': 162113,
#   'id': 6785,
#   'caption': 'A kitchen with a stove, sick, and dishes'},
#  {'image_id': 203564,
#   'id': 6802,
#   'caption': 'A clock with the appearance of the wheel of a bicycle '},
#  {'image_id': 368402,
#   'id': 6822,
#   'caption': 'A woman is holding a large pan in a kitchen. '},
#  {'image_id': 455384,
#   'id': 6841,
#   'caption': 'A truck with an ad for a television show painted on its side'},
#  {'image_id': 249352,
#   'id': 6842,
#   'caption': 'A small stall with large tiles, a toilet and two plungers'},
#  {'image_id': 567730,
#   'id': 6928,
#   'caption': 'A sign outside of a restaurant for Italian food. '},
#  {'image_id': 334015,
#   'id': 7032,
#   'caption': 'A public toilet stall with toilet paper and a cleaning brush.'},
#  {'image_id': 218026,
#   'id': 7039,
#   'caption': 'Two horses standing in a field across the stre.et from a building'},
#  {'image_id': 264461,
#   'id': 7049,
#   'caption': 'A squat toilet and a Western toilet are next to each other.'},
#  {'image_id': 22793,
#   'id': 7096,
#   'caption': "A men's restroom with a poster of a woman over the urinals."},
#  {'image_id': 527510,
#   'id': 7274,
#   'caption': 'A large military plane parked in the landing area.'},
#  {'image_id': 143370,
#   'id': 7337,
#   'caption': 'A bathroom with a white toilet and sink.'},
#  {'image_id': 455384,
#   'id': 7423,
#   'caption': "A large delivery truck with an advertisement painted on it's side."},
#  {'image_id': 249352,
#   'id': 7424,
#   'caption': 'A small restroom with a single toilet and wooden toilet seat.'},
#  {'image_id': 342387,
#   'id': 7454,
#   'caption': 'A group of people preparing food in a kitchen.'},
#  {'image_id': 141172,
#   'id': 7481,
#   'caption': "A blue door with a painting of a cat's rear end entering thru a cat door."},
#  {'image_id': 548498, 'id': 7522, 'caption': 'A cat is curled up in a bowl'},
#  {'image_id': 488327,
#   'id': 7627,
#   'caption': 'Posted signs point the way through a parking garage.'},
#  {'image_id': 202913,
#   'id': 7637,
#   'caption': 'A half eaten cake with coconut shavings and creme filling.'},
#  {'image_id': 352538,
#   'id': 7670,
#   'caption': "A leather purse laying on it's side on a green metal bench."},
#  {'image_id': 560591,
#   'id': 7679,
#   'caption': 'White toilet by built-in shelves in a tiled bathroom.'},
#  {'image_id': 400552,
#   'id': 7717,
#   'caption': 'A room filled with clutter and a fireplace.'},
#  {'image_id': 540860,
#   'id': 7732,
#   'caption': 'A green car on display next to a busy street.'},
#  {'image_id': 172851,
#   'id': 7748,
#   'caption': 'A large passenger jet taking off from an airport.'},
#  {'image_id': 486194,
#   'id': 7777,
#   'caption': 'Young woman carrying an opened umbrella in a city neighborhood.'},
#  {'image_id': 527510,
#   'id': 7799,
#   'caption': 'A U.S. Air Force plane sits on display.'},
#  {'image_id': 382406,
#   'id': 7911,
#   'caption': 'A woman walks her dog on a city sidewalk.'},
#  {'image_id': 202913,
#   'id': 7979,
#   'caption': 'Half of a cake sits on a plate.'},
#  {'image_id': 5247,
#   'id': 7993,
#   'caption': 'Two people on skis going through the woods.\n'},
#  {'image_id': 135161,
#   'id': 7996,
#   'caption': 'A photograph of a bathroom undergoing some renovations.'},
#  {'image_id': 143370,
#   'id': 8030,
#   'caption': 'Large bathroom with light flowing in the window.'},
#  {'image_id': 573223,
#   'id': 8051,
#   'caption': 'Little girl in blue dress standing in a bathroom. '},
#  {'image_id': 232223,
#   'id': 8083,
#   'caption': 'A fighter jet soars up into a blue sky.'},
#  {'image_id': 61259,
#   'id': 8089,
#   'caption': 'Virgin sponsored airplane parked with a plane leaving in the background.'},
#  {'image_id': 554037,
#   'id': 8091,
#   'caption': 'Cooking table with assorted fish and lemons with asparagus. '},
#  {'image_id': 491000,
#   'id': 8109,
#   'caption': 'A city street with people walking and vehicles on the road.'},
#  {'image_id': 436456,
#   'id': 8113,
#   'caption': 'Two men walking the tarmac of an airport.'},
#  {'image_id': 342387,
#   'id': 8198,
#   'caption': 'Group of people all sorting vegetables in a line.'},
#  {'image_id': 267802,
#   'id': 8206,
#   'caption': 'A crowded city street filled with traffic and bicycles.'},
#  {'image_id': 236148,
#   'id': 8226,
#   'caption': "An older man backing up a truck with a bicycle in it's flat bed."},
#  {'image_id': 133680,
#   'id': 8278,
#   'caption': 'Black man sitting on a bench behind a personal bicycle. '},
#  {'image_id': 139011,
#   'id': 8280,
#   'caption': 'Large group of people waiting for a train.'},
#  {'image_id': 115930,
#   'id': 8299,
#   'caption': 'A group of men standing in front of a bar having a conversation.'},
#  {'image_id': 459912,
#   'id': 8323,
#   'caption': 'Large set of motorcycles all lined up down a street.'},
#  {'image_id': 59171,
#   'id': 8357,
#   'caption': 'Group of three people sailing kites up in the sky. '},
#  {'image_id': 232223,
#   'id': 8380,
#   'caption': 'An old military jet fighter climbing in altitude.'},
#  {'image_id': 279806,
#   'id': 8427,
#   'caption': 'A man riding a dirt bike becomes airborne.'},
#  {'image_id': 358606,
#   'id': 8433,
#   'caption': 'A lit fire place in a living room next to a TV.'},
#  {'image_id': 75663,
#   'id': 8469,
#   'caption': 'A children play area absent of any children.'},
#  {'image_id': 104326,
#   'id': 8479,
#   'caption': 'An empty kitchen area painted green with bulbous lights.'},
#  {'image_id': 573223,
#   'id': 8495,
#   'caption': 'An adorable little girl in a blue dress stands in a restroom.'},
#  {'image_id': 352794,
#   'id': 8503,
#   'caption': 'Fruit in a jar filled with liquid sitting on a wooden table.'},
#  {'image_id': 315702,
#   'id': 8510,
#   'caption': 'A bathroom sink cluttered with multiple personal care items.'},
#  {'image_id': 410627,
#   'id': 8523,
#   'caption': 'A smiling man is cooking in his kitchen.'},
#  {'image_id': 59171,
#   'id': 8612,
#   'caption': 'A beautiful blue and pink sky overlooking the beach.'},
#  {'image_id': 410627,
#   'id': 8649,
#   'caption': 'A man smiles as he stirs his food in the pot.'},
#  {'image_id': 334015,
#   'id': 8724,
#   'caption': 'An empty, clean toilet stall with a stack of toilet paper.'},
#  {'image_id': 175954,
#   'id': 8739,
#   'caption': 'A work station in use inside an office.'},
#  {'image_id': 226419,
#   'id': 8754,
#   'caption': "An airplane with the letters 'MT' on it, flying in the sky."},
#  {'image_id': 484751,
#   'id': 8833,
#   'caption': 'Three computer screens showing a panoramic beach scene.'},
#  {'image_id': 126657,
#   'id': 8866,
#   'caption': 'A group of motorcyclists are driving down the city street.'},
#  {'image_id': 22793,
#   'id': 8881,
#   'caption': 'White tiled bathroom with line of tiles and Asian female poster on the wall'},
#  {'image_id': 267802,
#   'id': 8899,
#   'caption': 'An Asian intersection is full of mopeds and motorcycles.'},
#  {'image_id': 457834,
#   'id': 8986,
#   'caption': 'Elephants are in a long line with people on top of them.'},
#  {'image_id': 412151,
#   'id': 9006,
#   'caption': 'A bicycle store shows two males leaning toward a bike.'},
#  {'image_id': 427091,
#   'id': 9108,
#   'caption': 'City traffic and pedestrians are headed in multiple directions on the street.'},
#  {'image_id': 205577,
#   'id': 9113,
#   'caption': 'This is an apartment kitchen with white cabinets and appliances.'},
#  {'image_id': 369826,
#   'id': 9123,
#   'caption': 'A television is shown in the middle of a baggage claim area.'},
#  {'image_id': 226419,
#   'id': 9174,
#   'caption': 'A very large plane is flying through the sky.'},
#  {'image_id': 133680,
#   'id': 9178,
#   'caption': 'A man is sitting in a busy area with his bike.'},
#  {'image_id': 139011,
#   'id': 9180,
#   'caption': 'People are waiting in a city area to board a bus.'},
#  {'image_id': 32203,
#   'id': 9195,
#   'caption': 'There are some dirt bike riders taking a sharp turn'},
#  {'image_id': 525971,
#   'id': 9250,
#   'caption': 'A large group of motorcycle riders collect in a parking lot. '},
#  {'image_id': 238836,
#   'id': 9264,
#   'caption': 'The car is at the intersection while the sun is setting.'},
#  {'image_id': 238836,
#   'id': 9270,
#   'caption': 'A truck nears a stop light in rainy weather.'},
#  {'image_id': 175954,
#   'id': 9345,
#   'caption': 'A desk inside a library with a computer and several papers on it.'},
#  {'image_id': 354572,
#   'id': 9434,
#   'caption': 'People sitting under an umbrella looking at the scenery.'},
#  {'image_id': 143370,
#   'id': 9509,
#   'caption': 'A small bathroom with a toilet by the window and a pedestal sink with a mirrored medicine cabinet over it'},
#  {'image_id': 419074,
#   'id': 9564,
#   'caption': 'An airplane flying away in the cloudy sky.'},
#  {'image_id': 508672,
#   'id': 9575,
#   'caption': 'A bicycle chained to a rail near a flooded area.'},
#  {'image_id': 185360,
#   'id': 9595,
#   'caption': 'A cow standing next to a damaged car on a dirty lot.'},
#  {'image_id': 484751,
#   'id': 9616,
#   'caption': 'Three computer screens at a desk show a panoramic view of the ocean.'},
#  {'image_id': 175954,
#   'id': 9624,
#   'caption': 'A workstation with a computer, notebook, and papers.'},
#  {'image_id': 436456,
#   'id': 9673,
#   'caption': 'Two men at on an airport tarmac. \n'},
#  {'image_id': 571635,
#   'id': 9687,
#   'caption': 'A little bathrood decorated with many colorful objects'},
#  {'image_id': 486194,
#   'id': 9691,
#   'caption': 'A woman walking while holding up a red umbrella '},
#  {'image_id': 348306,
#   'id': 9696,
#   'caption': 'Bicycle leaning up against a welcome to Scotland sign.'},
#  {'image_id': 135161,
#   'id': 9709,
#   'caption': 'A bathroom being renovated featuring a toilette and shower.'},
#  {'image_id': 178761,
#   'id': 9718,
#   'caption': 'A sheep and a dog touching noses through a fence.'},
#  {'image_id': 573223,
#   'id': 9740,
#   'caption': 'A little girl in a blue dress stands in a bathroom.'},
#  {'image_id': 172851,
#   'id': 9845,
#   'caption': 'A plane that just took off flying from an airport.'},
#  {'image_id': 427091,
#   'id': 9861,
#   'caption': 'A city street busy with many cars driving as well as pedestrians'},
#  {'image_id': 412151,
#   'id': 9891,
#   'caption': 'A man adjust a bicycle in a bike shop with a child.'},
#  {'image_id': 369826,
#   'id': 9897,
#   'caption': 'An airport terminal has a big screen displaying an ad for Arizona.'},
#  {'image_id': 475593,
#   'id': 9977,
#   'caption': 'Women working in a commercial bakery or kitchen.'},
#  {'image_id': 352538,
#   'id': 9986,
#   'caption': 'A purse sits alone on a park bench.'},
#  {'image_id': 321064,
#   'id': 9990,
#   'caption': 'A small wooden table covered with delicious vegetables. '},
#  {'image_id': 175954,
#   'id': 10002,
#   'caption': 'An office desk with a lot of paperwork and a turned on computer'},
#  {'image_id': 263664,
#   'id': 10031,
#   'caption': 'A couple on a motorcycle in front of a bus and a metermaid car'},
#  {'image_id': 525971,
#   'id': 10045,
#   'caption': 'A street full of motorcycles and their riders'},
#  {'image_id': 459912,
#   'id': 10096,
#   'caption': 'A large group of motorcycles lined up on the street.'},
#  {'image_id': 468508,
#   'id': 10100,
#   'caption': 'A red motorcycle parked on a sidewalk near multi-story buildings.'},
#  {'image_id': 321064,
#   'id': 10107,
#   'caption': 'A dining table with a bowl of garlic cloves.'},
#  {'image_id': 348306,
#   'id': 10128,
#   'caption': 'A sign for a village in Scotland with a bicycle in front of it.'},
#  {'image_id': 538092,
#   'id': 10146,
#   'caption': 'A man standing in kitchen surrounded by items.'},
#  {'image_id': 31984,
#   'id': 10176,
#   'caption': 'A model standing next to a scooter in the middle of a room of people'},
#  {'image_id': 202658,
#   'id': 10187,
#   'caption': 'A toilette with a pink hello kitty toilette seat cover.'},
#  {'image_id': 202658,
#   'id': 10208,
#   'caption': 'A toilet with a Hello Kitty seat sitting in a room.'},
#  {'image_id': 175948,
#   'id': 10216,
#   'caption': 'Rather narrow bath room that appears to be being remodeled.'},
#  {'image_id': 135161,
#   'id': 10243,
#   'caption': 'A bathroom in the middle of a reconstruction phase.'},
#  {'image_id': 400552,
#   'id': 10264,
#   'caption': 'A small living room with a fireplace and work baskets.\n'},
#  {'image_id': 264461,
#   'id': 10325,
#   'caption': 'Mans bathroom with two visible fixtures, trash basket and plunger in sight.'},
#  {'image_id': 368402,
#   'id': 10359,
#   'caption': 'A woman cooking in a kitchen with granite counters.'},
#  {'image_id': 368402,
#   'id': 10533,
#   'caption': 'A woman cooking in her kitchen with a black pan.'},
#  {'image_id': 346071,
#   'id': 10539,
#   'caption': 'Some dogs stick their heads out the car window.'},
#  {'image_id': 352794,
#   'id': 10570,
#   'caption': 'Some yellow objects are floating in red liquid in a jar.'},
#  {'image_id': 322791,
#   'id': 10581,
#   'caption': 'An airplane is doing tricks and emitting smoke.'},
#  {'image_id': 491000,
#   'id': 10614,
#   'caption': 'A scenic photograph of an urban street with people and traffic.'},
#  {'image_id': 295768,
#   'id': 10625,
#   'caption': 'Computer monitor and accesories sitting on a desk.'},
#  {'image_id': 525971,
#   'id': 10657,
#   'caption': 'Several bikers are lined up in a parking lot.'},
#  {'image_id': 229067,
#   'id': 10667,
#   'caption': 'A group of people skiing down a snow covered slope.'},
#  {'image_id': 156324,
#   'id': 10668,
#   'caption': 'A woman takes a selfie in front of a bathroom mirror.'},
#  {'image_id': 508605,
#   'id': 10673,
#   'caption': 'Boy rides skateboard and does trick over stairs.'},
#  {'image_id': 268224,
#   'id': 10682,
#   'caption': 'Three young people in a kitchen pointing to a pizza.'},
#  {'image_id': 354572,
#   'id': 10718,
#   'caption': 'A person with a colorful umbrella sits on a fountain.'},
#  {'image_id': 206260,
#   'id': 10725,
#   'caption': 'Assorted flavored donuts being grabbed by multiple hands.'},
#  {'image_id': 489528,
#   'id': 10730,
#   'caption': 'An outside doorway to a restroom showing a destroyed wall and damaged floor.'},
#  {'image_id': 205577,
#   'id': 10733,
#   'caption': 'A shot of a kitchen with a microwave, sink, dishwasher, and refrigerator. '},
#  {'image_id': 229067,
#   'id': 10823,
#   'caption': 'Six people in snow field with ski equipment.'},
#  {'image_id': 156324,
#   'id': 10824,
#   'caption': 'Woman taking picture of self in bathroom mirror.'},
#  {'image_id': 218026,
#   'id': 10831,
#   'caption': 'Two mules eating grass in a parking lot in front of a hotel. '},
#  {'image_id': 238836,
#   'id': 10845,
#   'caption': 'A car is at a red light in the rain.'},
#  {'image_id': 27842,
#   'id': 10865,
#   'caption': 'A double sink with mirrors and a stool underneath it.'},
#  {'image_id': 263664,
#   'id': 10940,
#   'caption': 'A busy city street with a bus, taxi, and motorcycle.'},
#  {'image_id': 450308,
#   'id': 10947,
#   'caption': 'A man stands with his bike in ankle deep water in a flooded city.'},
#  {'image_id': 22793,
#   'id': 10951,
#   'caption': 'A mens restroom is lined up with urinals.'},
#  {'image_id': 175948,
#   'id': 10960,
#   'caption': 'Unfinished bathroom with broken toilet next to a bookshelf.'},
#  {'image_id': 342387,
#   'id': 10973,
#   'caption': 'Six different people in aprons and hats preparing vegetables'},
#  {'image_id': 279806,
#   'id': 10986,
#   'caption': 'A motorcyclist is in mid air hanging on to the handlebars.'},
#  {'image_id': 446409,
#   'id': 11053,
#   'caption': 'A tabby cat laying on a cat scratcher in front of a bicycle wheel. '},
#  {'image_id': 420958,
#   'id': 11083,
#   'caption': 'This a view from an airplane of the landscape below.'},
#  {'image_id': 571635,
#   'id': 11109,
#   'caption': 'A small bathroom containing a toilet and sink. '},
#  {'image_id': 523400,
#   'id': 11127,
#   'caption': 'A bathroom with double sinks, mirrors, toilet and towel racks.'},
#  {'image_id': 172851,
#   'id': 11138,
#   'caption': 'The airplane has begun its ascent in the skies.'},
#  {'image_id': 369826,
#   'id': 11142,
#   'caption': 'A flat screen TV with a picture of a person jumping on it.'},
#  {'image_id': 507362,
#   'id': 11200,
#   'caption': 'City street at night with several stop lights.'},
#  {'image_id': 40986,
#   'id': 11208,
#   'caption': 'Raw cookies in a pan on the counter and baked cookies in a pan on the stove.'},
#  {'image_id': 525971,
#   'id': 11221,
#   'caption': 'Motorcyclist meeting with one another before a ride.'},
#  {'image_id': 538092,
#   'id': 11235,
#   'caption': 'A kitchen area with a cooler and container stacked on the floor and a man getting an item out of a cabinet.'},
#  {'image_id': 59171,
#   'id': 11252,
#   'caption': 'Group of people are flying kites on the beach.'},
#  {'image_id': 27842,
#   'id': 11279,
#   'caption': 'There are two sinks in the clean bathroom.'},
#  {'image_id': 264461,
#   'id': 11315,
#   'caption': 'A toilet stall, complete with two clean toilets.'},
#  {'image_id': 141172,
#   'id': 11318,
#   'caption': 'A blue door with a picture of a cat door with cats backside hanging out on it.'},
#  {'image_id': 61259,
#   'id': 11329,
#   'caption': 'One airplane is taking off from an airport while others are parked.'},
#  {'image_id': 554037,
#   'id': 11331,
#   'caption': 'A kitchen counter with cutting board, knife and food.'},
#  {'image_id': 321064,
#   'id': 11460,
#   'caption': 'A kitchen table with a juicer and vegetable on it.'},
#  {'image_id': 236148,
#   'id': 11508,
#   'caption': 'A man looking out the back window of his truck.'},
#  {'image_id': 488327,
#   'id': 11512,
#   'caption': 'Three traffic signs at the entrance of a parking garage. '},
#  {'image_id': 571635,
#   'id': 11517,
#   'caption': 'Bathroom containing a toilet, a sink and a wicker basket.'},
#  {'image_id': 107960,
#   'id': 11523,
#   'caption': 'A motorcycle moves forward down an empty street.'},
#  {'image_id': 400552,
#   'id': 11542,
#   'caption': 'A room with a fir place and several baskets and a bench in the background.'},
#  {'image_id': 523400,
#   'id': 11574,
#   'caption': 'A fancy bathroom with his and her mirrors and sinks next to a toilette.'},
#  {'image_id': 420958,
#   'id': 11605,
#   'caption': 'A view from a window on board an airplane flying in the sky.'},
#  {'image_id': 141172,
#   'id': 11615,
#   'caption': 'A picture of a cat door is on the bottom corner of a blue door.'},
#  {'image_id': 8045,
#   'id': 11673,
#   'caption': 'Tub and shower on platform in modern tiled bathroom.'},
#  {'image_id': 264461,
#   'id': 11702,
#   'caption': 'A bathroom with an odd toilette next to a normal toilette.'},
#  {'image_id': 322791,
#   'id': 11724,
#   'caption': 'An aerial stunt plane in a climb with smoke coming out of the back.'},
#  {'image_id': 525971,
#   'id': 11740,
#   'caption': 'There is no picture or image sorry sorry'},
#  {'image_id': 508672,
#   'id': 11777,
#   'caption': 'A bicycle leans against a fence near some flood waters.'},
#  {'image_id': 484751,
#   'id': 11821,
#   'caption': 'A desk with multiple computer screens forming one large screen.'},
#  {'image_id': 529691,
#   'id': 11842,
#   'caption': 'A row of park benches on the side of a green grassy hill. '},
#  {'image_id': 486194,
#   'id': 11860,
#   'caption': 'A beautiful young lady walking in the rain while holding an umbrella.'},
#  {'image_id': 202658,
#   'id': 11897,
#   'caption': 'A broken toilet bowl with  a Hello Kitty toilet seat cover.'},
#  {'image_id': 482597,
#   'id': 11931,
#   'caption': 'A man in an ATV is moving the cows along.'},
#  {'image_id': 205577,
#   'id': 11933,
#   'caption': 'A kitchen with a refrigerator, microwave, dishwasher and sink.'},
#  {'image_id': 82673,
#   'id': 11969,
#   'caption': 'A scooter is parked behind a red car.'},
#  {'image_id': 540860,
#   'id': 11986,
#   'caption': 'A sculpture of a green hot rod on a city sidewalk'},
#  {'image_id': 51191,
#   'id': 11990,
#   'caption': 'The view of a large bathroom with a walk in closet.'},
#  {'image_id': 488327,
#   'id': 12007,
#   'caption': 'Three road signs posted in a parking garage.'},
#  {'image_id': 295768,
#   'id': 12014,
#   'caption': 'An Apple computer on a table next to an iPhone and an iPad.'},
#  {'image_id': 8045,
#   'id': 12111,
#   'caption': 'A bathroom with a shower combination tub and sink.'},
#  {'image_id': 27842,
#   'id': 12137,
#   'caption': 'A bathroom with his and her mirrors and sinks.'},
#  {'image_id': 115930,
#   'id': 12169,
#   'caption': 'Restaurant staff taking a break near the bar.'},
#  {'image_id': 75663,
#   'id': 12189,
#   'caption': 'A craft supply room with craft supplies and containers.'},
#  {'image_id': 354572,
#   'id': 12197,
#   'caption': 'A man with a colored umbrella sits on a monument.'},
#  {'image_id': 249371,
#   'id': 12217,
#   'caption': 'Many sheep grazing in a large, green pasture.'},
#  {'image_id': 408364,
#   'id': 12261,
#   'caption': "A young man standing next to a race car with the red sox logo on it's hood."},
#  {'image_id': 267862,
#   'id': 12312,
#   'caption': 'A guy sitting on his motorcycle while a woman stands beside him'},
#  {'image_id': 115930,
#   'id': 12313,
#   'caption': 'Several men having a conversation at a restaurant.'},
#  {'image_id': 232223,
#   'id': 12349,
#   'caption': 'A fighter jet flying through the sky with smoke coming off of it.'},
#  {'image_id': 402514,
#   'id': 12356,
#   'caption': 'A man plays the violin in a home.'},
#  {'image_id': 482597,
#   'id': 12426,
#   'caption': 'A man is riding a tractor following some cows.'},
#  {'image_id': 6672,
#   'id': 12427,
#   'caption': 'A door for exiting and entering the house in the kitchen.'},
#  {'image_id': 436456,
#   'id': 12433,
#   'caption': 'Two young men walking down a runway toward an airplane.'},
#  {'image_id': 540860,
#   'id': 12496,
#   'caption': 'A sculpture of a hot rod sitting on a sidewalk.'},
#  {'image_id': 536321,
#   'id': 12500,
#   'caption': 'An adorable caleco cat sitting underneath a bicycle.'},
#  {'image_id': 148272,
#   'id': 12501,
#   'caption': 'An adorable cat attempts to hide in a purse to steal the persons identity.'},
#  {'image_id': 279806,
#   'id': 12540,
#   'caption': 'A person performs a stunt jump on a motorcycle.'},
#  {'image_id': 412151,
#   'id': 12564,
#   'caption': 'The bike shop employee is helping a customer. '},
#  {'image_id': 36450,
#   'id': 12570,
#   'caption': 'A very big teddy bear is next to a woman.'},
#  {'image_id': 249371,
#   'id': 12583,
#   'caption': 'Many sheep graze in a grassy pasture in a valley. '},
#  {'image_id': 523400,
#   'id': 12597,
#   'caption': 'A bathroom with a double sink and mirrors.'},
#  {'image_id': 138599,
#   'id': 12627,
#   'caption': 'A BMW motor cycle parked next to shrub..'},
#  {'image_id': 206260,
#   'id': 12639,
#   'caption': 'A group of people with a bunch of doughnuts. '},
#  {'image_id': 358606,
#   'id': 12675,
#   'caption': 'A brick fireplace with fire adorned with knick-knacks.'},
#  {'image_id': 82673,
#   'id': 12713,
#   'caption': 'A small car parked in by a vespa.'},
#  {'image_id': 354572,
#   'id': 12731,
#   'caption': 'A man sis on a public area while holding an umbrella.'},
# ...
#  {'image_id': 75118,
#   'id': 24200,
#   'caption': 'A red and white jet plane releasing chemtrails.'},
#  {'image_id': 428769,
#   'id': 24202,
#   'caption': 'A black car withe license plate SUPABAAD parked next to a parking meter.'},
#  {'image_id': 370462,
#   'id': 24205,
#   'caption': 'A ski lodge covered in snow next a mountain filled with trees.'},
#  {'image_id': 69236,
#   'id': 24239,
#   'caption': 'A park and walkway lined with benches and bushes.'},
#  {'image_id': 364113,
#   'id': 24267,
#   'caption': 'Two people riding different colored horses down a dirty road.'},
#  {'image_id': 104381,
#   'id': 24278,
#   'caption': 'A car sitting at a stop light at dusk.'},
#  {'image_id': 322604,
#   'id': 24314,
#   'caption': 'People on motorcycles riding in the street in a parade.'},
#  {'image_id': 43098,
#   'id': 24328,
#   'caption': 'A man walking down the sidewalk, and a blue briefcase in front of a post.'},
#  {'image_id': 231846,
#   'id': 24365,
#   'caption': 'A brown cat sitting in a bathroom sink.'},
#  {'image_id': 301574,
#   'id': 24383,
#   'caption': 'Three people on red motorcycles stopped and showing off.'},
#  {'image_id': 349804,
#   'id': 24402,
#   'caption': 'A monument depicting three fighter planes attached to the ground.'},
#  {'image_id': 8180,
#   'id': 24474,
#   'caption': 'A jet airliner waits its turn on the runway.'},
#  {'image_id': 79920,
#   'id': 24537,
#   'caption': 'A living room with a large tv and pictures all around.'},
#  {'image_id': 93959,
#   'id': 24539,
#   'caption': 'There is nobody in the kitchen right now.'},
#  {'image_id': 408364,
#   'id': 24546,
#   'caption': 'A young boy  standing by a Red Sox car wearing Red Sox shirt and visor'},
#  {'image_id': 30423,
#   'id': 24591,
#   'caption': 'Four giraffes are standing in front of some trees.'},
#  {'image_id': 498547,
#   'id': 24663,
#   'caption': 'A kitchen with a large stove and a lot of pots.'},
#  {'image_id': 468858,
#   'id': 24664,
#   'caption': 'The living room is empty and the television is turned off.'},
#  {'image_id': 56070,
#   'id': 24667,
#   'caption': 'A black and orange motorcycle on a sidewalk.'},
#  {'image_id': 494629,
#   'id': 24681,
#   'caption': 'A man sits on a toilet while working on his computer at his desk.'},
#  {'image_id': 61422,
#   'id': 24687,
#   'caption': 'A bathroom with a sink and a toilet. '},
#  {'image_id': 548706,
#   'id': 24744,
#   'caption': 'A bathroom with checkered tile and maroon towels.'},
#  {'image_id': 385757,
#   'id': 24779,
#   'caption': 'A car coming to a stop sign as seen from inside the car.'},
#  {'image_id': 11334,
#   'id': 24785,
#   'caption': 'An ornate building has a clock tower near by.'},
#  {'image_id': 146961,
#   'id': 24804,
#   'caption': 'A man is cooking in a crowded kitchen.'},
#  {'image_id': 155997,
#   'id': 24847,
#   'caption': 'A dog in a basket being carried by its owner.'},
#  {'image_id': 306313,
#   'id': 24930,
#   'caption': 'A kitchen that features and oven that has a light turned on in it.'},
#  {'image_id': 9288,
#   'id': 24948,
#   'caption': 'A toilet in a restroom next to a toilet paper dispenser'},
#  {'image_id': 510992,
#   'id': 24953,
#   'caption': 'a white stoves burners with a green timer and some decorations'},
#  {'image_id': 278237,
#   'id': 24954,
#   'caption': 'a bus and two cars are going down a two way street'},
#  {'image_id': 555472,
#   'id': 24971,
#   'caption': 'An elephant crossing the road in front of an SUV.\n'},
#  {'image_id': 175024,
#   'id': 24978,
#   'caption': 'A person on a motorcycle with a stuffed animal on back.'},
#  {'image_id': 262594,
#   'id': 24983,
#   'caption': 'A small group of people standing around a small motor bike.'},
#  {'image_id': 79920,
#   'id': 24993,
#   'caption': 'A flat screen TV sitting next to a fireplace in a living room.'},
#  {'image_id': 93959,
#   'id': 24998,
#   'caption': 'A kitchen with lots of cupboards and counter space.'},
#  {'image_id': 136783,
#   'id': 25006,
#   'caption': 'A rock wall next to a green tiled room.'},
#  {'image_id': 301574,
#   'id': 25040,
#   'caption': 'Three red motorcycles with riders in protective gear are on the street.'},
#  {'image_id': 372413,
#   'id': 25051,
#   'caption': 'Man hangs off side of motorcycle during race as spectators look on. '},
#  {'image_id': 175024,
#   'id': 25062,
#   'caption': 'A motorcyclist riding with a stuffed animal attached to the back.'},
#  {'image_id': 120157,
#   'id': 25069,
#   'caption': 'A toilet bowl with no toilet seat in a restroom'},
#  {'image_id': 5879,
#   'id': 25099,
#   'caption': 'Two people riding their bikes in the street.'},
#  {'image_id': 548706,
#   'id': 25125,
#   'caption': 'A bathroom with a checkered black and white tile floor'},
#  {'image_id': 555472,
#   'id': 25148,
#   'caption': 'Elephant walking through the middle of the road in front of a car. '},
#  {'image_id': 555472,
#   'id': 25154,
#   'caption': 'An elephant crossing the road in front of a car.'},
#  {'image_id': 39430,
#   'id': 25160,
#   'caption': 'Two sheep peeking over the wall at something.'},
#  {'image_id': 193680,
#   'id': 25164,
#   'caption': 'Full grown cat laying down and sleeping on top of a car. '},
#  {'image_id': 30423,
#   'id': 25206,
#   'caption': 'Four giraffes standing in front of trees on a grassy field. '},
#  {'image_id': 322604,
#   'id': 25229,
#   'caption': 'Ladies riding down the street on motorcycles as others look on.'},
#  {'image_id': 565635,
#   'id': 25232,
#   'caption': 'two lines of motorcycles driving down the road while a crowd watches'},
#  {'image_id': 561780,
#   'id': 25255,
#   'caption': 'A group of older people sitting on a park bench with a dog on a leash.'},
#  {'image_id': 262594,
#   'id': 25262,
#   'caption': 'A man standing next to a motorcycle on asphalt.'},
#  {'image_id': 90732,
#   'id': 25277,
#   'caption': 'A girl in a kitchen on a booster stool washing dishes.'},
#  {'image_id': 230600,
#   'id': 25288,
#   'caption': 'A toilet on the outside of a building next to a parking meter.'},
#  {'image_id': 14297,
#   'id': 25327,
#   'caption': 'A boat home sitting on a river bay.'},
#  {'image_id': 215708,
#   'id': 25388,
#   'caption': 'People standing around a cake with candles in it.'},
#  {'image_id': 231846,
#   'id': 25412,
#   'caption': 'An orange tabby cat lying in a bathroom sink.'},
#  {'image_id': 43098,
#   'id': 25414,
#   'caption': 'A blue suitcase is leaning against a post on the street while a man walks by.'},
#  {'image_id': 237920,
#   'id': 25487,
#   'caption': 'The front view of a building that has a bench, and chairs located in front. '},
#  {'image_id': 193680,
#   'id': 25491,
#   'caption': 'A cat napping on a red car in a driveway.'},
#  {'image_id': 241876,
#   'id': 25505,
#   'caption': 'A blurry picture of a cat standing on a toilet.'},
#  {'image_id': 34474,
#   'id': 25506,
#   'caption': 'The interior of a house with lots of wood detailing.'},
#  {'image_id': 43098,
#   'id': 25507,
#   'caption': 'A man walking past a suitcase and street lamp'},
#  {'image_id': 69293,
#   'id': 25511,
#   'caption': 'The bathroom toilet with the cover up, sink, and bathroom items are shown.'},
#  {'image_id': 145523,
#   'id': 25516,
#   'caption': 'A photo of a toilet with items on the tank.'},
#  {'image_id': 349344,
#   'id': 25581,
#   'caption': 'A car show features a yellow hot wheels car.'},
#  {'image_id': 193680,
#   'id': 25614,
#   'caption': 'A orange cat taking a nap on top of a car.'},
#  {'image_id': 56070,
#   'id': 25651,
#   'caption': 'A shiny motorcycle is parked on a city sidewalk.'},
#  {'image_id': 81505,
#   'id': 25689,
#   'caption': 'An american eagle commercial plane flying in the sky'},
#  {'image_id': 81505,
#   'id': 25692,
#   'caption': 'A commercial airplane flies through the sky to its destination. '},
#  {'image_id': 306313,
#   'id': 25701,
#   'caption': 'The front view of the stove built within the counter. '},
#  {'image_id': 565635,
#   'id': 25712,
#   'caption': 'A lot of spectators  watch a motorcade on Washington D.C. '},
#  {'image_id': 262594,
#   'id': 25733,
#   'caption': 'A person holding upright an older motorcycle that looks to be retrofitted.'},
#  {'image_id': 241876,
#   'id': 25766,
#   'caption': 'A cat standing on the toilet bowl seat'},
#  {'image_id': 34474,
#   'id': 25767,
#   'caption': 'A bathroom with dark wooden fixtures  and shelving'},
#  {'image_id': 69293,
#   'id': 25778,
#   'caption': 'a bathroom with a sink and a toilet near a scale'},
#  {'image_id': 123843,
#   'id': 25802,
#   'caption': 'The view of the shower, sink, and towel rack.'},
#  {'image_id': 369979,
#   'id': 25816,
#   'caption': 'Several pieces of art and a painting on display'},
#  {'image_id': 322604,
#   'id': 25844,
#   'caption': 'a gay parade with some lesbians on motorcycles'},
#  {'image_id': 193680,
#   'id': 25851,
#   'caption': 'A fluffy cat sleeping on top of a red car.'},
#  {'image_id': 32054,
#   'id': 25906,
#   'caption': 'a dog standing near a street sign on a dirt road'},
#  {'image_id': 525667,
#   'id': 25919,
#   'caption': 'A group of women are describing a new setup for a building plan'},
#  {'image_id': 364113,
#   'id': 25935,
#   'caption': 'Two people riding horses along  a trail'},
#  {'image_id': 494629,
#   'id': 26049,
#   'caption': 'A man sitting on a toilet in front of the computer.'},
#  {'image_id': 555472,
#   'id': 26063,
#   'caption': 'Elephant crossing road in front of SUV vehicle,'},
#  {'image_id': 21711,
#   'id': 26085,
#   'caption': 'Motorcyclists and a bicycle are parked on a yard.'},
#  {'image_id': 30423,
#   'id': 26148,
#   'caption': 'Several giraffe somewhat distant standing on the edge of a wooded area.'},
#  {'image_id': 106900,
#   'id': 26216,
#   'caption': 'A man and a woman walking in the snow with a dog. '},
#  {'image_id': 325374,
#   'id': 26256,
#   'caption': 'A sheep in the field being shorn by a man.'},
#  {'image_id': 237920,
#   'id': 26273,
#   'caption': 'A brightly colored store front with benches and chairs.'},
#  {'image_id': 175024,
#   'id': 26277,
#   'caption': 'A person in full leather riding a motorcycle with a stuff animal on the back.'},
#  {'image_id': 349344,
#   'id': 26337,
#   'caption': 'People at a auto show viewing very fancy cars.'},
#  {'image_id': 93959,
#   'id': 26429,
#   'caption': 'A nicely decorated kitchen area with white cabinets '},
#  {'image_id': 281950,
#   'id': 26435,
#   'caption': 'A toilet next to a wall in the bathroom. '},
#  {'image_id': 293153,
#   'id': 26446,
#   'caption': 'The sightseeing boat streams along the river joined by a plane'},
#  {'image_id': 32054,
#   'id': 26455,
#   'caption': 'A thin dog is standing by a marker in the road. '},
#  {'image_id': 21711,
#   'id': 26460,
#   'caption': 'A couple people on motocross bikes, and a couple other people standing around.'},
#  {'image_id': 281950,
#   'id': 26492,
#   'caption': 'A toilet in a bathroom with stone walls.'},
#  {'image_id': 436972,
#   'id': 26501,
#   'caption': 'A police man standing on tip of his motorcycle.'},
#  {'image_id': 300216,
#   'id': 26661,
#   'caption': 'a white bathroom a sink and a brown mirror'},
#  {'image_id': 61422,
#   'id': 26670,
#   'caption': 'A modern and clean bathroom with a big sink.'},
#  {'image_id': 293153,
#   'id': 26704,
#   'caption': 'a photo of  a boat with an airplane in back'},
#  {'image_id': 146961,
#   'id': 26709,
#   'caption': 'A man cooking in the kitchen in front of the stove. '},
#  {'image_id': 127585,
#   'id': 26728,
#   'caption': 'A room with a chair and couch and multiple books.'},
#  {'image_id': 155997,
#   'id': 26740,
#   'caption': 'A man riding a bike with a wooden trainer attached and a dog riding in it.'},
#  {'image_id': 312724,
#   'id': 26750,
#   'caption': 'A herd of of wild animals walking around a field surrounded by forest.'},
#  {'image_id': 20788,
#   'id': 26755,
#   'caption': 'A woman hovering over food on a wooden table.'},
#  {'image_id': 369763,
#   'id': 26760,
#   'caption': 'A man and police officer on the sidewalk next to a motorcycle.'},
#  {'image_id': 443351,
#   'id': 26767,
#   'caption': 'Two motorcycles parked on black pavement side by side.'},
#  {'image_id': 364113,
#   'id': 26781,
#   'caption': 'Two people riding horses along a scenic trail.'},
#  {'image_id': 75118,
#   'id': 26813,
#   'caption': 'a decorated jet plane flying in the sky leaving a traill of smoke'},
#  {'image_id': 19523,
#   'id': 26822,
#   'caption': 'a boy and girl are putting their bicycles on the front of a bus'},
#  {'image_id': 424378,
#   'id': 26857,
#   'caption': 'A man with glasses riding in a car with an adorable dog in the backseat.'},
#  {'image_id': 400456,
#   'id': 26881,
#   'caption': 'A man riding on the back of a brown horse in front of a truck.'},
#  {'image_id': 14297,
#   'id': 26920,
#   'caption': 'A house boat with many bikes on a riverbank.'},
#  {'image_id': 300216,
#   'id': 26952,
#   'caption': 'A bathroom sink underneath a mirror and tooth brushes.'},
#  {'image_id': 564911,
#   'id': 27045,
#   'caption': 'An airplane that is on the landing strip.'},
#  {'image_id': 525667,
#   'id': 27065,
#   'caption': 'a group of people in a field of grass near a building'},
#  {'image_id': 19523,
#   'id': 27068,
#   'caption': 'A man with a bicycle stands in front of a bus.'},
#  {'image_id': 155997,
#   'id': 27076,
#   'caption': 'A man on a bike pulling a dog in a cart.'},
#  {'image_id': 281950,
#   'id': 27101,
#   'caption': 'A toilet and plunger in a rustic bathroom.'},
#  {'image_id': 424378,
#   'id': 27145,
#   'caption': 'A man driving with his dog in the back seat.'},
#  {'image_id': 445002,
#   'id': 27148,
#   'caption': 'A bathroom with two sinks and an enclosed shower.'},
#  {'image_id': 262594,
#   'id': 27152,
#   'caption': 'A person standing beside a unique moped on a street.'},
#  {'image_id': 186697,
#   'id': 27174,
#   'caption': 'A peson riding a bike down a long narrow road.'},
#  {'image_id': 489528,
#   'id': 27212,
#   'caption': 'A broken door frame showing a a bathroom with a cement floor and a broken back wall'},
#  {'image_id': 260409,
#   'id': 27224,
#   'caption': 'A motorcyclist in his helmet parked along side a road near the ocean'},
#  {'image_id': 301574,
#   'id': 27251,
#   'caption': 'Three drivers wearing helmets sitting on their motorcycles.'},
#  {'image_id': 69293,
#   'id': 27254,
#   'caption': 'A very small brown colored bathroom with a white toilet.'},
#  {'image_id': 549386,
#   'id': 27289,
#   'caption': 'Two people stand outside of a very old building.'},
#  {'image_id': 120157,
#   'id': 27337,
#   'caption': 'A toilet in a restroom next to a trash can.'},
#  {'image_id': 237920,
#   'id': 27341,
#   'caption': 'Benches and chairs set outside a building with cathedral doors.'},
#  {'image_id': 564911,
#   'id': 27411,
#   'caption': 'Big commercial airplane getting ready to take off.'},
#  {'image_id': 104381,
#   'id': 27434,
#   'caption': 'The a car that is stopped at a red light at an intersection'},
#  {'image_id': 293153,
#   'id': 27439,
#   'caption': 'A ferry moved through the water while an airplane flies overhead.'},
#  {'image_id': 69236,
#   'id': 27482,
#   'caption': 'Two back to back wooden benches next to a shrub near a stone walkway'},
#  {'image_id': 428769,
#   'id': 27484,
#   'caption': 'A mercedez benz car is parked next to a parking meter.'},
#  {'image_id': 370210,
#   'id': 27488,
#   'caption': 'Two adorable dogs hanging out of a car door window.'},
#  {'image_id': 531111,
#   'id': 27489,
#   'caption': 'A bathroom with a checkered floor and an enclosed shower.'},
#  {'image_id': 193680,
#   'id': 27564,
#   'caption': 'An orange cat sleeping on top of a red car.'},
#  {'image_id': 123843,
#   'id': 27671,
#   'caption': 'A white and bright bathroom with silver fixtures.'},
#  {'image_id': 385757,
#   'id': 27683,
#   'caption': 'Picture taken inside a car at a stop sign of fall foliage.'},
#  {'image_id': 336384,
#   'id': 27692,
#   'caption': 'An airliner taking off from an airport runway.'},
#  {'image_id': 443351,
#   'id': 27721,
#   'caption': 'Two different motorcycles angle parked on a street.'},
#  {'image_id': 312724,
#   'id': 27755,
#   'caption': 'Zebras, giraffes and kudus on the run across a plain.'},
#  {'image_id': 436972,
#   'id': 27827,
#   'caption': 'The cop was standing on his bike for fun.'},
#  {'image_id': 230600,
#   'id': 27832,
#   'caption': 'A toilet sitting on the street next to a parking machine.'},
#  {'image_id': 251075,
#   'id': 27841,
#   'caption': 'A bathroom with a tan sink and white toliet.'},
#  ...]

# %%
rootDir = 'dataset'
annotations = os.path.join(rootDir, 'annotations')

splits = ['train2017', 'val2017']

all_rows = []

for split in splits:
    anotationFile = os.path.join(annotations, f'captions_{split}.json')
    with open(anotationFile, 'r') as f:
        data = json.load(f)

    image_id_to_filename = {img['id']: img['file_name'] for img in data['images']}

    image_id_to_captions = defaultdict(list)
    for ann in data['annotations']:
        image_id_to_captions[ann['image_id']].append(ann['caption'])

    for image_id, captions in image_id_to_captions.items():
        captions = captions[:5] + [''] * (5 - len(captions))
        image_path = os.path.join(rootDir, split, image_id_to_filename[image_id])
        all_rows.append([image_path] + captions)

# %%
columns = ['image_path', 'caption1', 'caption2', 'caption3', 'caption4', 'caption5']
dataFrame = pd.DataFrame(all_rows, columns=columns)

print("Total images:", len(dataFrame))
dataFrame.to_csv('dataset/COCO2017.csv', index=False)
dataFrame.head(10)
# Out:
# Total images: 123287
#                            image_path  \
# 0  dataset/train2017/000000203564.jpg
# 1  dataset/train2017/000000322141.jpg
# 2  dataset/train2017/000000016977.jpg
# 3  dataset/train2017/000000106140.jpg
# 4  dataset/train2017/000000571635.jpg
# 5  dataset/train2017/000000301837.jpg
# 6  dataset/train2017/000000315702.jpg
# 7  dataset/train2017/000000189634.jpg
# 8  dataset/train2017/000000472598.jpg
# 9  dataset/train2017/000000162113.jpg
#
#                                             caption1  \
# 0  A bicycle replica with a clock as the front wh...
# 1  A room with blue walls and a white sink and door.
# 2  A car that seems to be parked illegally behind...
# 3  A large passenger airplane flying through the ...
# 4        A bathroom with a toilet, sink, and shower.
# 5  A long empty, minimal modern skylit home kitchen.
# 6    A bathroom sink with toiletries on the counter.
# 7     This is an open box containing four cucumbers.
# 8  An old-fashioned green station wagon is parked...
# 9  A gas stove next to a stainless steel kitchen ...
#
#                                             caption2  \
# 0                    The bike has a clock as a tire.
# 1   Blue and white color scheme in a small bathroom.
# 2      two cars parked on the sidewalk on the street
# 3  There is a GOL plane taking off in a partly cl...
# 4      A full bathroom with a wicker laundry basket.
# 5       A picture of a modern looking kitchen area\n
# 6  A bathroom sink and various personal hygiene i...
# 7  An open food container box with four unknown f...
# 8      An old teal colored car parked on the street.
# 9  A kitchen stove, sink, and counter with stuff ...
#
#                                             caption3  \
# 0  A black metal bicycle with a clock inside the ...
# 1  This is a blue and white bathroom with a wall ...
# 2          City street with parked cars and a bench.
# 3  An airplane that is, either, landing or just t...
# 4  A little bathrood decorated with many colorful...
# 5  A narrow kitchen ending with a chrome refriger...
# 6  A messy bathroom countertop perched atop black...
# 7    A small box filled with four green vegetables.
# 8  A classic car sitting beside the road with a s...
# 9    A kitchen with a stove, sink, and drying area.
#
#                                             caption4  \
# 0  A bicycle figurine in which the front wheel is...
# 1  A blue boat themed bathroom with a life preser...
# 2  Cars try to maneuver into parking spaces along...
# 3    An red and white airplane is in the cloudy sky.
# 4    A small bathroom containing a toilet and sink.
# 5  A narrow kitchen is decorated in shades of whi...
# 6  A bathroom vanity with cabinets and basin sink...
# 7          An opened box of four chocolate bananas.
# 8  An old green car parked on the side of the str...
# 9   This is a kitchen with dishes and a silver sink.
#
#                                             caption5
# 0  A clock with the appearance of the wheel of a ...
# 1  A bathroom with walls that are painted baby blue.
# 2  A couple of cars parked in a busy street sidew...
# 3        A passenger plane taking off into the sky.
# 4  Bathroom containing a toilet, a sink and a wic...
# 5         a room that has a stove and a icebox in it
# 6  A bathroom sink cluttered with multiple person...
# 7     An open box contains an unknown, purple object
# 8    An antique, turquoise car is parked at the curb
# 9           A kitchen with a stove, sick, and dishes
